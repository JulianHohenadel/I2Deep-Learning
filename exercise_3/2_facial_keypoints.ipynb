# %% [markdown]
# # Facial Keypoint Detection
#
# This project will be all about defining and training a convolutional neural network to perform facial keypoint detection, and using computer vision techniques to transform images of faces.  The first step in any challenge like this will be to load and visualize the data you'll be working with.
#
# Let's take a look at some examples of images and corresponding facial keypoints.
#
# Facial keypoints (also called facial landmarks) are the small magenta dots shown on each of the faces in the image above. In images, there are faces and **keypoints, with coordinates (x, y)**.  These keypoints mark important areas of the face: the eyes, corners of the mouth, the nose, etc. These keypoints are relevant for a variety of tasks, such as face filters, emotion recognition, pose recognition, and so on.
#
# ---

# %%
from google.colab import drive, files
drive.mount('/content/drive')

# %%
# !mkdir exercise_code
# !mkdir exercise_code/classifiers/
# !mkdir exercise_code/rnn
# !mkdir models

# %%
# !lscpu | grep 'Model name'
# !lscpu | grep 'Thread(s) per core'
# !nvidia-smi -L
# !nvidia-smi
# Out:
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz
# Thread(s) per core:  2
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-56f1f503-81d0-2965-472b-0f6a79849008)
# Sat Jan 11 17:19:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 250W |     10MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Load and Visualize Data
#
# The first step in working with any dataset is to become familiar with your data; you'll need to load in the images of faces and their keypoints and visualize them!
#
# #### Training and Testing Data
#
# This facial keypoints dataset consists of thousands gray images. All of these images are separated into either a training or a test set of data.
#
# * training images are for you to use as you create a model to predict keypoints.
# * test images are unknown to you, which will be used to test the accuracy of your model.
#
# The information about the images and keypoints in this dataset are summarized in CSV files, which we can read in using `pandas`. Let's read the training CSV and get the annotations in an (N, 2) array where N is the number of keypoints and 2 is the dimension of the keypoint coordinates (x, y).
#
# ---

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Note</h3>
#     <p>Sometimes you will be presented with csv data. The default python csv reader is ok, but for more efficient data manipulation, it is recommended to use <b>pandas</b>.</p>
# </div>

# %%
# import the required libraries
import glob
import os
from os import path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from exercise_code.vis_utils import show_all_keypoints


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Training data size
#
# The training data is in csv file. There are 6750 images in training data, where the first 30 columns are the keypoints coordinates (x, y),
# and the 31th column is the image content. We provide you the function `get_image` and `get_keypoints` function to get i-th image and i-th set of keypoints.

# %%
# Google drive path: /content/drive/My Drive/datasets/landmark_data/training.csv
if path.exists('../datasets/landmark_data/training.csv'):
    key_pts_frame = pd.read_csv('../datasets/landmark_data/training.csv')
    print("training key_pts loaded from local")
else:
    key_pts_frame = pd.read_csv('/content/drive/My Drive/datasets/landmark_data/training.csv')
    print("training key_pts loaded from remote")
    
key_pts_frame.describe().loc['count'].plot.bar()
print(key_pts_frame.shape)
# Out:
# training key_pts loaded from remote
# (6451, 31)

# %% [markdown]
# From visulization, we can see not every image contains full landmarks, therefore we need to delete those without full landmarks. And after dropping, we have almost 2k images left as our training data.

# %%
# Drop if not full landmarks
key_pts_frame.dropna(inplace=True)
key_pts_frame.describe().loc['count'].plot.bar()
print(key_pts_frame.shape)
# Out:
# (1546, 31)

# %%
from exercise_code.data_utils import get_keypoints
from exercise_code.data_utils import get_image

n = 0
image = get_image(n, key_pts_frame)
keypoints = get_keypoints(n, key_pts_frame)
print('image size: {}'.format(image.shape))
print('keypoints size: {}'.format(keypoints.shape))
# Out:
# image size: (96, 96)
# keypoints size: (15, 2)

# %% [markdown]
# Below, is a function `show_all_keypoints` that takes in an image and keypoints and displays them.  As you look at this data, **note that these images are not all of the same quality**!

# %%
# select an image by index in our data frame
for n in range(5):
    image = get_image(n, key_pts_frame)
    key_pts = get_keypoints(n, key_pts_frame)
    show_all_keypoints(image, key_pts)

# %% [markdown]
# ## Dataset class and Transformations
#
# To prepare our data for training, we'll be using PyTorch's Dataset class. Much of this this code is a modified version of what can be found in the [PyTorch data loading tutorial](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html).
#
# #### Dataset class
#
# ``torch.utils.data.Dataset`` is an abstract class representing a
# dataset. This class will allow us to load batches of image/keypoint data, and uniformly apply transformations to our data, such as rescaling and normalizing images for training a neural network.
#
#
# Your custom dataset should inherit ``Dataset`` and override the following
# methods:
#
# -  ``__len__`` so that ``len(dataset)`` returns the size of the dataset.
# -  ``__getitem__`` to support the indexing such that ``dataset[i]`` can
#    be used to get the i-th sample of image/keypoint data.
#
# Let's create a dataset class for our face keypoints dataset. We will
# read the CSV file in ``__init__`` but leave the reading of images to
# ``__getitem__``.
#
# A sample of our dataset will be a dictionary
# ``{'image': image, 'keypoints': key_pts}``. Our dataset will take an
# optional argument ``transform`` so that any required processing can be
# applied on the sample. We will see the usefulness of ``transform`` in the future.
# #### TODO: Implement a custom dataset for face keypoints in `exercise_code/dataloader.py` file

# %%
from exercise_code.dataloader import FacialKeypointsDataset

# Construct the dataset
# Google drive path: /content/drive/My Drive/datasets/landmark_data/training.csv
if path.exists('../datasets/landmark_data/training.csv'):
    face_dataset = FacialKeypointsDataset(csv_file='../datasets/landmark_data/training.csv')
    print("face_dataset loaded from local")
else:
    face_dataset = FacialKeypointsDataset(csv_file='/content/drive/My Drive/datasets/landmark_data/training.csv')
    print("face_dataset loaded from remote")

# print some stats about the dataset
print('Length of dataset: ', len(face_dataset))
# Out:
# face_dataset loaded from remote
# Length of dataset:  1546

# %% [markdown]
# Now that we've defined this class, let's instantiate the dataset and display some images.

# %%
# Display a few of the images from the dataset
num_to_display = 5

for i in range(num_to_display):
    
    # define the size of images
    fig = plt.figure(figsize=(20,10))
    
    # randomly select a sample
    rand_i = np.random.randint(0, len(face_dataset))
    print("random idx: " + str(rand_i))
    sample = face_dataset[rand_i]

    # print the shape of the image and keypoints
    print('index: {}'.format(i))
    print('image size: {}'.format(sample['image'].shape))
    print('keypoint shape: {}'.format(sample['keypoints'].shape))

    ax = plt.subplot(1, num_to_display, i + 1)
    ax.set_title('Sample #{}'.format(i))
    
    # Using the same display function, defined earlier
    show_all_keypoints(sample['image'][0], sample['keypoints'])
# Out:
# random idx: 1014
# index: 0
# image size: (1, 96, 96)
# keypoint shape: (15, 2)
# random idx: 328
# index: 1
# image size: (1, 96, 96)
# keypoint shape: (15, 2)
# random idx: 914
# index: 2
# image size: (1, 96, 96)
# keypoint shape: (15, 2)
# random idx: 42
# index: 3
# image size: (1, 96, 96)
# keypoint shape: (15, 2)
# random idx: 796
# index: 4
# image size: (1, 96, 96)
# keypoint shape: (15, 2)

# %% [markdown]
# ## Transforms
#
# Neural networks often expect images that are standardized; a fixed size, with a normalized range for color ranges and coordinates, and (for PyTorch) converted from numpy lists and arrays to Tensors.
#
# Therefore, we will need to write some pre-processing code.
# Let's create 2 transforms:
#
# -  ``Normalize``: to convert grayscale values with a range of [0, 1] and normalize the keypoints to be in a range of about [-1, 1]
# -  ``ToTensor``: to convert numpy images to torch images.
#
#
# We will use the default transforms from torchvision
#
# Observe below how these transforms are generally applied to both the image and its keypoints.

# %%
try:
    import torch
except ImportError:
    print("import torch failed.\n" + "Downloading...\n")
    # !pip3 install torch
    print("Done.")
print("torch version: " + str(torch.__version__))
from torchvision import transforms, utils
# tranforms

from exercise_code.transforms import Normalize, ToTensor
# Out:
# torch version: 1.3.1

# %% [markdown]
# ## Test out the transforms
#
# Let's test these transforms out to make sure they behave as expected.

# %% [markdown]
# ## Create the transformed dataset
#
# Apply the transforms in order to normalized images and landmarks. Verify that your transform works by printing out the shape of the resulting data (printing out a few examples should show you a consistent tensor size).
#
# #### Hint: you can also implement or use some other default PyTorch data augmenatiton methods to improve your scores!

# %%
# define the data tranform
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Normalize(),
                                     ToTensor()])

# create the transformed dataset
# Construct the dataset
# Google drive path: /content/drive/My Drive/datasets/landmark_data/training.csv
if path.exists('../datasets/landmark_data/training.csv'):
    transformed_dataset = FacialKeypointsDataset(
        csv_file='../datasets/landmark_data/training.csv', 
        transform=data_transform)
    print("transformed_dataset loaded from local")
else:
    transformed_dataset = FacialKeypointsDataset(
        csv_file='/content/drive/My Drive/datasets/landmark_data/training.csv', 
        transform=data_transform)
    print("transformed_dataset loaded from remote")
# Out:
# transformed_dataset loaded from remote

# %%
# print some stats about the transformed data
print('Number of images: ', len(transformed_dataset))

# make sure the sample tensors are the expected size
for i in range(5):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())

# Display a few of the images from the dataset
num_to_display = 5

for i in range(num_to_display):
    
    # define the size of images
    fig = plt.figure(figsize=(20,10))
    
    # randomly select a sample
    rand_i = np.random.randint(0, len(transformed_dataset))
    print("random idx: " + str(rand_i))
    sample = transformed_dataset[rand_i]

    # print the shape of the image and keypoints
    print('index: {}'.format(i))
    print('image size: {}'.format(sample['image'].shape))
    print('keypoint shape: {}'.format(sample['keypoints'].shape))

    ax = plt.subplot(1, num_to_display, i + 1)
    ax.set_title('Sample #{}'.format(i))
    
    # Using the same display function, defined earlier
    show_all_keypoints(sample['image'][0], sample['keypoints'])
# Out:
# Number of images:  1546
# 0 torch.Size([1, 96, 96]) torch.Size([15, 2])
# 1 torch.Size([1, 96, 96]) torch.Size([15, 2])
# 2 torch.Size([1, 96, 96]) torch.Size([15, 2])
# 3 torch.Size([1, 96, 96]) torch.Size([15, 2])
# 4 torch.Size([1, 96, 96]) torch.Size([15, 2])
# random idx: 486
# index: 0
# image size: torch.Size([1, 96, 96])
# keypoint shape: torch.Size([15, 2])
# random idx: 1056
# index: 1
# image size: torch.Size([1, 96, 96])
# keypoint shape: torch.Size([15, 2])
# random idx: 1053
# index: 2
# image size: torch.Size([1, 96, 96])
# keypoint shape: torch.Size([15, 2])
# random idx: 606
# index: 3
# image size: torch.Size([1, 96, 96])
# keypoint shape: torch.Size([15, 2])
# random idx: 1538
# index: 4
# image size: torch.Size([1, 96, 96])
# keypoint shape: torch.Size([15, 2])

# %% [markdown]
# ## Data Iteration and Batching
#
# Right now, we are iterating over this data using a ``for`` loop, but we are missing out on a lot of PyTorch's dataset capabilities, specifically the abilities to:
#
# -  Batch the data
# -  Shuffle the data
# -  Load the data in parallel using ``multiprocessing`` workers.
#
# ``torch.utils.data.DataLoader`` is an iterator which provides all these
# features, and we'll see how this is used, when we load data in batches to train a neural network! Then we can define a DataLoader class from PyTorch with transformed dataset, with batch size 4, shuffle functionality and multithreading with 4 workers.
#
# #### Note: num_workers > 0 might throw an error on machines without cuda. You might consider leaving num_workers=0 if you are working on CPU
#
# ---

# %%
from torch.utils.data import DataLoader
batch_size = 20
train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# #### TODO: Define your model in the provided file `exercise_code/classifiers/keypoint_nn.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %%
from exercise_code.classifiers.keypoint_nn import KeypointModel
model = KeypointModel()
print(model)
# Out:
# KeypointModel(
#   (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(2, 2), stride=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (dropout4): Dropout(p=0.4, inplace=False)
#   (dropout5): Dropout(p=0.5, inplace=False)
#   (dropout6): Dropout(p=0.6, inplace=False)
#   (fc1): Linear(in_features=6400, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=500, bias=True)
#   (fc3): Linear(in_features=500, out_features=30, bias=True)
# )

# %%
# Display a few output samples from our network
def show_sample_outputs(image, keypoints):
    model.eval()  
    # define the size of images
    fig = plt.figure(figsize=(20,20))
     
    # Predict with model
    predicted_keypoints = model(image)[0]
    # Cast back to (x,y)-coordinates
    predicted_keypoints = predicted_keypoints.view(-1, 2).detach()

    # Undo data normalization
    image = torch.squeeze(image) * 255.
    keypoints = (keypoints.view(-1, 2) * 48) + 48
    predicted_keypoints = (predicted_keypoints * 48) + 48

    # print the shape of the image and keypoints
    print('index: {}'.format(i))
    print('image shape: {}'.format(image.shape))
    print('gt keypoints shape: {}'.format(keypoints.shape))
    print('predict keypoints shape: {}'.format(predicted_keypoints.shape))
    
    # Print data loader image
    ax = plt.subplot(4, 1, 1)
    ax.set_title('Sample #{}: Dataloader'.format(i))
    # Using the same display function, defined earlier
    show_all_keypoints(image, keypoints)

    # Print predicted image
    ax = plt.subplot(1, 1, 1)
    ax.set_title('Sample #{}: Prediction'.format(i))
    # Using the same display function, defined earlier
    show_all_keypoints(image, predicted_keypoints)
    plt.show()
    
num_to_display = 3
for idx, sample in enumerate(train_loader):
    if idx == num_to_display:
        break
    show_sample_outputs(sample['image'][0:1], sample['keypoints'][0:1])
# Out:
# index: 4
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 4
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 4
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])

# %% [markdown]
# ## Training your network
# We define the sovler for you to use, basically it takes out the data from the DataLoader, and via PyTorch functions to run forward and backward pass. If you want define your own solver, it is also welcome, feel free to change to achieve your best scores)

# %%
import torch.optim as optim
from torch import nn
from exercise_code.classifiers.keypoint_nn import KeypointModel

def save_checkpoint(epoch, model, optimizer, loss):
    model_save_name = "checkpoint_epoch_" + str(epoch) + ".pth"
    cp_path = F"/content/drive/My Drive/Checkpoints/{model_save_name}"
    if not path.exists(cp_path):
        print("--------------------------------------")
        print("Creating checkpoint on epoch: " + str(epoch))
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss
            }, cp_path)
        print("Checkpoint created on epoch: " + str(epoch))
        print("--------------------------------------")

def load_checkpoint(path):
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']
    print("Checkpoint loaded")
    return model, optimizer, epoch, loss

def train_net(n_epochs):

    # prepare the net for training
    # init running_loss
    # init best_metric
    model.train()
    running_loss = 0.0
    best_metric = 500
    best_model = None

    # checkpoint creation interval
    interval = 50

    # True  = creating checkpoints
    # False = pass
    check = False

    # True  = evaluating metric
    # False = pass
    eval_metric = True

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            #print(key_pts[0], images[0])

            # forward pass to get outputs
            output_pts = model(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()

            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()
            running_loss += loss.item()

            # print loss statistics
            if batch_i % 20 == 9:    # print every 20 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(
                    epoch,
                    batch_i + 1, 
                    running_loss / (len(train_loader) * epoch + batch_i)))
            
            if epoch % interval == 0 and epoch is not 0 and check:
                save_checkpoint(epoch, model, optimizer, loss)
        if eval_metric:
            metric = Evaluate(model)
            if metric > best_metric:
                print("NEW BEST!")
                model.save("models/keypoints_nn.model")
                print("Done.")
                best_metric = metric
                best_model = model
    print('Finished Training')
    # files.download("models/keypoints_nn.model")
    return best_model

# Load model and run the solver
model = KeypointModel()
criterion = nn.MSELoss()
# optimizer = optim.SGD(model.parameters(), lr=0.01, 
#                       momentum=0.9, weight_decay=1e-6, nesterov=True)
optimizer = optim.Adam(model.parameters())
model = train_net(n_epochs=75)
# Out:
# Epoch: 0, Batch: 10, Avg. Loss: 0.06648069123427074
# Epoch: 0, Batch: 30, Avg. Loss: 0.03567172050604533
# Epoch: 0, Batch: 50, Avg. Loss: 0.027840555531485955
# Epoch: 0, Batch: 70, Avg. Loss: 0.02333210424884506
# Metric on VAL data: 1.8968958345167175
# Epoch: 1, Batch: 10, Avg. Loss: 0.022293278374762714
# Epoch: 1, Batch: 30, Avg. Loss: 0.020907899786970604
# Epoch: 1, Batch: 50, Avg. Loss: 0.01949713363378184
# Epoch: 1, Batch: 70, Avg. Loss: 0.018281360305719026
# Metric on VAL data: 12.224124981973292
# Epoch: 2, Batch: 10, Avg. Loss: 0.01769152189689604
# Epoch: 2, Batch: 30, Avg. Loss: 0.01713484460487962
# Epoch: 2, Batch: 50, Avg. Loss: 0.016367521384594644
# Epoch: 2, Batch: 70, Avg. Loss: 0.015697189008610116
# Metric on VAL data: 41.55944401259831
# Epoch: 3, Batch: 10, Avg. Loss: 0.01522723963070247
# Epoch: 3, Batch: 30, Avg. Loss: 0.014743313862598667
# Epoch: 3, Batch: 50, Avg. Loss: 0.014280079240341385
# Epoch: 3, Batch: 70, Avg. Loss: 0.01391357372640924
# Metric on VAL data: 81.29083515792743
# Epoch: 4, Batch: 10, Avg. Loss: 0.013557500221891288
# Epoch: 4, Batch: 30, Avg. Loss: 0.013278680777073431
# Epoch: 4, Batch: 50, Avg. Loss: 0.012997169317187448
# Epoch: 4, Batch: 70, Avg. Loss: 0.012706217978130097
# Metric on VAL data: 80.53512188722553
# Epoch: 5, Batch: 10, Avg. Loss: 0.01247941821528818
# Epoch: 5, Batch: 30, Avg. Loss: 0.012250563946634815
# Epoch: 5, Batch: 50, Avg. Loss: 0.012140100182231372
# Epoch: 5, Batch: 70, Avg. Loss: 0.01198414728970699
# Metric on VAL data: 165.1348087410999
# Epoch: 6, Batch: 10, Avg. Loss: 0.011795243684717882
# Epoch: 6, Batch: 30, Avg. Loss: 0.01160721747313347
# Epoch: 6, Batch: 50, Avg. Loss: 0.011432212901732216
# Epoch: 6, Batch: 70, Avg. Loss: 0.011273801955437805
# Metric on VAL data: 145.85013014403475
# Epoch: 7, Batch: 10, Avg. Loss: 0.011163800246677957
# Epoch: 7, Batch: 30, Avg. Loss: 0.011020915326054977
# Epoch: 7, Batch: 50, Avg. Loss: 0.010886260885119188
# Epoch: 7, Batch: 70, Avg. Loss: 0.010757970188297635
# Metric on VAL data: 146.8150426417076
# Epoch: 8, Batch: 10, Avg. Loss: 0.010649742223145837
# Epoch: 8, Batch: 30, Avg. Loss: 0.01052628793492685
# Epoch: 8, Batch: 50, Avg. Loss: 0.010395518549057872
# Epoch: 8, Batch: 70, Avg. Loss: 0.010271286883513735
# Metric on VAL data: 126.19550032571405
# Epoch: 9, Batch: 10, Avg. Loss: 0.010166381785722054
# Epoch: 9, Batch: 30, Avg. Loss: 0.010052608990488847
# Epoch: 9, Batch: 50, Avg. Loss: 0.009946738139722501
# Epoch: 9, Batch: 70, Avg. Loss: 0.009841851208808356
# Metric on VAL data: 76.08743238125588
# Epoch: 10, Batch: 10, Avg. Loss: 0.00975007115726339
# Epoch: 10, Batch: 30, Avg. Loss: 0.009647124298135617
# Epoch: 10, Batch: 50, Avg. Loss: 0.00954104466414342
# Epoch: 10, Batch: 70, Avg. Loss: 0.00944760691750799
# Metric on VAL data: 142.26002171993247
# Epoch: 11, Batch: 10, Avg. Loss: 0.009361973872908843
# Epoch: 11, Batch: 30, Avg. Loss: 0.009264675454890698
# Epoch: 11, Batch: 50, Avg. Loss: 0.009182684927256705
# Epoch: 11, Batch: 70, Avg. Loss: 0.009098577940285993
# Metric on VAL data: 177.84826563730434
# Epoch: 12, Batch: 10, Avg. Loss: 0.009022611859821218
# Epoch: 12, Batch: 30, Avg. Loss: 0.00893494999639381
# Epoch: 12, Batch: 50, Avg. Loss: 0.00885043958495111
# Epoch: 12, Batch: 70, Avg. Loss: 0.008766123062157216
# Metric on VAL data: 178.72055422400015
# Epoch: 13, Batch: 10, Avg. Loss: 0.008690948487247612
# Epoch: 13, Batch: 30, Avg. Loss: 0.00860980904258409
# Epoch: 13, Batch: 50, Avg. Loss: 0.00854254556974871
# Epoch: 13, Batch: 70, Avg. Loss: 0.008472436849614356
# Metric on VAL data: 185.8323931228449
# Epoch: 14, Batch: 10, Avg. Loss: 0.008406812915972669
# Epoch: 14, Batch: 30, Avg. Loss: 0.008331432031761659
# Epoch: 14, Batch: 50, Avg. Loss: 0.00826254026559455
# Epoch: 14, Batch: 70, Avg. Loss: 0.008191146879215483
# Metric on VAL data: 131.94007186713924
# Epoch: 15, Batch: 10, Avg. Loss: 0.00812329020666352
# Epoch: 15, Batch: 30, Avg. Loss: 0.0080600697844304
# Epoch: 15, Batch: 50, Avg. Loss: 0.007993539936047497
# Epoch: 15, Batch: 70, Avg. Loss: 0.007931440002965208
# Metric on VAL data: 204.56850693900435
# Epoch: 16, Batch: 10, Avg. Loss: 0.007881252337936179
# Epoch: 16, Batch: 30, Avg. Loss: 0.00782312563939214
# Epoch: 16, Batch: 50, Avg. Loss: 0.007763490761912435
# Epoch: 16, Batch: 70, Avg. Loss: 0.00770339386162172
# Metric on VAL data: 192.30644694538472
# Epoch: 17, Batch: 10, Avg. Loss: 0.007655432980423898
# Epoch: 17, Batch: 30, Avg. Loss: 0.007594719906148546
# Epoch: 17, Batch: 50, Avg. Loss: 0.007541183045133949
# Epoch: 17, Batch: 70, Avg. Loss: 0.00748592894440884
# Metric on VAL data: 173.74333948406198
# Epoch: 18, Batch: 10, Avg. Loss: 0.007435465283772294
# Epoch: 18, Batch: 30, Avg. Loss: 0.007384104644119303
# Epoch: 18, Batch: 50, Avg. Loss: 0.007334075830152537
# Epoch: 18, Batch: 70, Avg. Loss: 0.007282186868914782
# Metric on VAL data: 244.42666037859763
# Epoch: 19, Batch: 10, Avg. Loss: 0.00723524630977944
# Epoch: 19, Batch: 30, Avg. Loss: 0.007181366051600853
# Epoch: 19, Batch: 50, Avg. Loss: 0.0071324036437786925
# Epoch: 19, Batch: 70, Avg. Loss: 0.007084538731099539
# Metric on VAL data: 242.5919180393434
# Epoch: 20, Batch: 10, Avg. Loss: 0.0070416714712369585
# Epoch: 20, Batch: 30, Avg. Loss: 0.0069937146649167855
# Epoch: 20, Batch: 50, Avg. Loss: 0.006948355599662498
# Epoch: 20, Batch: 70, Avg. Loss: 0.006901826659198039
# Metric on VAL data: 200.7265124741044
# Epoch: 21, Batch: 10, Avg. Loss: 0.006861203105986779
# Epoch: 21, Batch: 30, Avg. Loss: 0.006821811091362644
# Epoch: 21, Batch: 50, Avg. Loss: 0.006777103428872965
# Epoch: 21, Batch: 70, Avg. Loss: 0.006733642549237087
# Metric on VAL data: 126.01406286574063
# Epoch: 22, Batch: 10, Avg. Loss: 0.006699117750091397
# Epoch: 22, Batch: 30, Avg. Loss: 0.00665792360111943
# Epoch: 22, Batch: 50, Avg. Loss: 0.006615119816329088
# Epoch: 22, Batch: 70, Avg. Loss: 0.006574932891218101
# Metric on VAL data: 304.6001751791083
# Epoch: 23, Batch: 10, Avg. Loss: 0.006537075411397664
# Epoch: 23, Batch: 30, Avg. Loss: 0.006497201808187774
# Epoch: 23, Batch: 50, Avg. Loss: 0.006459870754879592
# Epoch: 23, Batch: 70, Avg. Loss: 0.006422064400510987
# Metric on VAL data: 352.05306665732064
# Epoch: 24, Batch: 10, Avg. Loss: 0.006389906821841278
# Epoch: 24, Batch: 30, Avg. Loss: 0.006353769478998561
# Epoch: 24, Batch: 50, Avg. Loss: 0.006318535859903097
# Epoch: 24, Batch: 70, Avg. Loss: 0.006281449922695391
# Metric on VAL data: 240.02606521688384
# Epoch: 25, Batch: 10, Avg. Loss: 0.006249987360718981
# Epoch: 25, Batch: 30, Avg. Loss: 0.006215112675073123
# Epoch: 25, Batch: 50, Avg. Loss: 0.006179901576853017
# Epoch: 25, Batch: 70, Avg. Loss: 0.006146037421793985
# Metric on VAL data: 275.01439328721574
# Epoch: 26, Batch: 10, Avg. Loss: 0.0061169465230873875
# Epoch: 26, Batch: 30, Avg. Loss: 0.006083588367264661
# Epoch: 26, Batch: 50, Avg. Loss: 0.006050605958795779
# Epoch: 26, Batch: 70, Avg. Loss: 0.0060167521681116064
# Metric on VAL data: 349.94221599322015
# Epoch: 27, Batch: 10, Avg. Loss: 0.005986303980649399
# Epoch: 27, Batch: 30, Avg. Loss: 0.005954403507433814
# Epoch: 27, Batch: 50, Avg. Loss: 0.005924054479827184
# Epoch: 27, Batch: 70, Avg. Loss: 0.005894049223426772
# Metric on VAL data: 351.21262261585747
# Epoch: 28, Batch: 10, Avg. Loss: 0.005865755586723962
# Epoch: 28, Batch: 30, Avg. Loss: 0.005835313151693212
# Epoch: 28, Batch: 50, Avg. Loss: 0.005806384373806998
# Epoch: 28, Batch: 70, Avg. Loss: 0.0057769702554007025
# Metric on VAL data: 408.4646401974492
# Epoch: 29, Batch: 10, Avg. Loss: 0.005750594224864047
# Epoch: 29, Batch: 30, Avg. Loss: 0.0057223344239292874
# Epoch: 29, Batch: 50, Avg. Loss: 0.005696756677040754
# Epoch: 29, Batch: 70, Avg. Loss: 0.005668428783478389
# Metric on VAL data: 432.25282455343563
# Epoch: 30, Batch: 10, Avg. Loss: 0.005642633153101459
# Epoch: 30, Batch: 30, Avg. Loss: 0.005616777316009042
# Epoch: 30, Batch: 50, Avg. Loss: 0.005589641615104783
# Epoch: 30, Batch: 70, Avg. Loss: 0.005562706000042864
# Metric on VAL data: 411.3937642739432
# Epoch: 31, Batch: 10, Avg. Loss: 0.005537500635733836
# Epoch: 31, Batch: 30, Avg. Loss: 0.005512050220685351
# Epoch: 31, Batch: 50, Avg. Loss: 0.005485532454850721
# Epoch: 31, Batch: 70, Avg. Loss: 0.00546011954250513
# Metric on VAL data: 373.1137678334676
# Epoch: 32, Batch: 10, Avg. Loss: 0.00543837724760093
# Epoch: 32, Batch: 30, Avg. Loss: 0.005413856755637813
# Epoch: 32, Batch: 50, Avg. Loss: 0.005389989143940081
# Epoch: 32, Batch: 70, Avg. Loss: 0.0053649402205373
# Metric on VAL data: 469.72769916199877
# Epoch: 33, Batch: 10, Avg. Loss: 0.00534380159546858
# Epoch: 33, Batch: 30, Avg. Loss: 0.005319196340818312
# Epoch: 33, Batch: 50, Avg. Loss: 0.00529483818579387
# Epoch: 33, Batch: 70, Avg. Loss: 0.005271763593704425
# Metric on VAL data: 468.2570004935153
# Epoch: 34, Batch: 10, Avg. Loss: 0.005250105118665639
# Epoch: 34, Batch: 30, Avg. Loss: 0.005227707106304306
# Epoch: 34, Batch: 50, Avg. Loss: 0.005206077197255958
# Epoch: 34, Batch: 70, Avg. Loss: 0.00518418976348934
# Metric on VAL data: 459.808976201787
# Epoch: 35, Batch: 10, Avg. Loss: 0.005164907220802051
# Epoch: 35, Batch: 30, Avg. Loss: 0.005144127521221028
# Epoch: 35, Batch: 50, Avg. Loss: 0.00512305594222153
# Epoch: 35, Batch: 70, Avg. Loss: 0.0051031474275022035
# Metric on VAL data: 478.44833356401887
# Epoch: 36, Batch: 10, Avg. Loss: 0.0050858187886437005
# Epoch: 36, Batch: 30, Avg. Loss: 0.005064988878747966
# Epoch: 36, Batch: 50, Avg. Loss: 0.005043970861598995
# Epoch: 36, Batch: 70, Avg. Loss: 0.005023796880892247
# Metric on VAL data: 472.335054462952
# Epoch: 37, Batch: 10, Avg. Loss: 0.005006010493783148
# Epoch: 37, Batch: 30, Avg. Loss: 0.004985925642850188
# Epoch: 37, Batch: 50, Avg. Loss: 0.004966918131125555
# Epoch: 37, Batch: 70, Avg. Loss: 0.004947726051370391
# Metric on VAL data: 515.2593875096815
# NEW BEST!
# Saving model... models/keypoints_nn.model
# Done.
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type KeypointModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 38, Batch: 10, Avg. Loss: 0.004930796204908575
# Epoch: 38, Batch: 30, Avg. Loss: 0.004911217243419049
# Epoch: 38, Batch: 50, Avg. Loss: 0.004894222282505339
# Epoch: 38, Batch: 70, Avg. Loss: 0.004876085156748336
# Metric on VAL data: 584.6534396010551
# NEW BEST!
# Saving model... models/keypoints_nn.model
# Done.
# Epoch: 39, Batch: 10, Avg. Loss: 0.004860406022632427
# Epoch: 39, Batch: 30, Avg. Loss: 0.0048425729018877145
# Epoch: 39, Batch: 50, Avg. Loss: 0.004824392323010694
# Epoch: 39, Batch: 70, Avg. Loss: 0.0048074739583944875
# Metric on VAL data: 408.59300910589036
# Epoch: 40, Batch: 10, Avg. Loss: 0.004792307373823836
# Epoch: 40, Batch: 30, Avg. Loss: 0.004775924640902868
# Epoch: 40, Batch: 50, Avg. Loss: 0.00475960988395619
# Epoch: 40, Batch: 70, Avg. Loss: 0.004743169130432992
# Metric on VAL data: 550.97669007694
# Epoch: 41, Batch: 10, Avg. Loss: 0.004727721713932878
# Epoch: 41, Batch: 30, Avg. Loss: 0.0047107487021915695
# Epoch: 41, Batch: 50, Avg. Loss: 0.004693741499963192
# Epoch: 41, Batch: 70, Avg. Loss: 0.004676632363958393
# Metric on VAL data: 566.2311791287199
# Epoch: 42, Batch: 10, Avg. Loss: 0.004663230915471651
# Epoch: 42, Batch: 30, Avg. Loss: 0.00464719849034197
# Epoch: 42, Batch: 50, Avg. Loss: 0.004630777099435883
# Epoch: 42, Batch: 70, Avg. Loss: 0.004615405615369033
# Metric on VAL data: 577.9590976010699
# Epoch: 43, Batch: 10, Avg. Loss: 0.004601299837774423
# Epoch: 43, Batch: 30, Avg. Loss: 0.004585269136638432
# Epoch: 43, Batch: 50, Avg. Loss: 0.004571326132096096
# Epoch: 43, Batch: 70, Avg. Loss: 0.004556134092019397
# Metric on VAL data: 497.4087140954133
# Epoch: 44, Batch: 10, Avg. Loss: 0.004542875426949431
# Epoch: 44, Batch: 30, Avg. Loss: 0.004527861490437739
# Epoch: 44, Batch: 50, Avg. Loss: 0.004513789692868742
# Epoch: 44, Batch: 70, Avg. Loss: 0.0044994050949722555
# Metric on VAL data: 511.02847357517976
# Epoch: 45, Batch: 10, Avg. Loss: 0.004486055496728625
# Epoch: 45, Batch: 30, Avg. Loss: 0.004472294498517095
# Epoch: 45, Batch: 50, Avg. Loss: 0.004458573212780123
# Epoch: 45, Batch: 70, Avg. Loss: 0.004444597767052907
# Metric on VAL data: 598.5534212822023
# NEW BEST!
# Saving model... models/keypoints_nn.model
# Done.
# Epoch: 46, Batch: 10, Avg. Loss: 0.004432816684198423
# Epoch: 46, Batch: 30, Avg. Loss: 0.004419859445665185
# Epoch: 46, Batch: 50, Avg. Loss: 0.0044060630589974024
# Epoch: 46, Batch: 70, Avg. Loss: 0.004392610644281933
# Metric on VAL data: 540.1593442133554
# Epoch: 47, Batch: 10, Avg. Loss: 0.004379798115870985
# Epoch: 47, Batch: 30, Avg. Loss: 0.004366011768283325
# Epoch: 47, Batch: 50, Avg. Loss: 0.00435351079554218
# Epoch: 47, Batch: 70, Avg. Loss: 0.004340517946669814
# Metric on VAL data: 579.335213262956
# Epoch: 48, Batch: 10, Avg. Loss: 0.004328724120520482
# Epoch: 48, Batch: 30, Avg. Loss: 0.004316056897946931
# Epoch: 48, Batch: 50, Avg. Loss: 0.004304091816954904
# Epoch: 48, Batch: 70, Avg. Loss: 0.004292347696534078
# Metric on VAL data: 380.728869554635
# Epoch: 49, Batch: 10, Avg. Loss: 0.004282513881121409
# Epoch: 49, Batch: 30, Avg. Loss: 0.004270691584222071
# Epoch: 49, Batch: 50, Avg. Loss: 0.004258263477875395
# Epoch: 49, Batch: 70, Avg. Loss: 0.004245951139664675
# Metric on VAL data: 589.8609260973383
# Epoch: 50, Batch: 10, Avg. Loss: 0.004235510737641152
# Epoch: 50, Batch: 30, Avg. Loss: 0.004224647471218302
# Epoch: 50, Batch: 50, Avg. Loss: 0.00421355716617286
# Epoch: 50, Batch: 70, Avg. Loss: 0.00420213120096192
# Metric on VAL data: 546.3046395304314
# Epoch: 51, Batch: 10, Avg. Loss: 0.004191794423210094
# Epoch: 51, Batch: 30, Avg. Loss: 0.004180522820181793
# Epoch: 51, Batch: 50, Avg. Loss: 0.004169852301788981
# Epoch: 51, Batch: 70, Avg. Loss: 0.004158975967556544
# Metric on VAL data: 497.52769666264106
# Epoch: 52, Batch: 10, Avg. Loss: 0.00415130912083995
# Epoch: 52, Batch: 30, Avg. Loss: 0.004143782323648107
# Epoch: 52, Batch: 50, Avg. Loss: 0.004135681056456094
# Epoch: 52, Batch: 70, Avg. Loss: 0.004126478308868227
# Metric on VAL data: 492.72237362030694
# Epoch: 53, Batch: 10, Avg. Loss: 0.00411825504848244
# Epoch: 53, Batch: 30, Avg. Loss: 0.0041094593511744005
# Epoch: 53, Batch: 50, Avg. Loss: 0.004100932393740919
# Epoch: 53, Batch: 70, Avg. Loss: 0.0040911369045871495
# Metric on VAL data: 346.45153057782136
# Epoch: 54, Batch: 10, Avg. Loss: 0.004088309681092894
# Epoch: 54, Batch: 30, Avg. Loss: 0.004088376866567039
# Epoch: 54, Batch: 50, Avg. Loss: 0.0040909296002307185
# Epoch: 54, Batch: 70, Avg. Loss: 0.004090296374255375
# Metric on VAL data: 195.50416888421825
# Epoch: 55, Batch: 10, Avg. Loss: 0.004091168017453525
# Epoch: 55, Batch: 30, Avg. Loss: 0.00408934818922095
# Epoch: 55, Batch: 50, Avg. Loss: 0.004088504015296135
# Epoch: 55, Batch: 70, Avg. Loss: 0.004087185178740011
# Metric on VAL data: 206.69110270697627
# Epoch: 56, Batch: 10, Avg. Loss: 0.0040845131059618735
# Epoch: 56, Batch: 30, Avg. Loss: 0.004081689770906835
# Epoch: 56, Batch: 50, Avg. Loss: 0.004082289074001699
# Epoch: 56, Batch: 70, Avg. Loss: 0.004083112080826858
# Metric on VAL data: 186.2568730997697
# Epoch: 57, Batch: 10, Avg. Loss: 0.004085053859422805
# Epoch: 57, Batch: 30, Avg. Loss: 0.0040873439070461684
# Epoch: 57, Batch: 50, Avg. Loss: 0.004088835407139627
# Epoch: 57, Batch: 70, Avg. Loss: 0.004090474448852645
# Metric on VAL data: 164.13859856332837
# Epoch: 58, Batch: 10, Avg. Loss: 0.00409043729052559
# Epoch: 58, Batch: 30, Avg. Loss: 0.004092397302106455
# Epoch: 58, Batch: 50, Avg. Loss: 0.00409451016558307
# Epoch: 58, Batch: 70, Avg. Loss: 0.004097673582408278
# Metric on VAL data: 139.30185258928182
# Epoch: 59, Batch: 10, Avg. Loss: 0.004099584689785568
# Epoch: 59, Batch: 30, Avg. Loss: 0.004101960263286398
# Epoch: 59, Batch: 50, Avg. Loss: 0.004105106537484419
# Epoch: 59, Batch: 70, Avg. Loss: 0.0041074139667980755
# Metric on VAL data: 137.13193778801377
# Epoch: 60, Batch: 10, Avg. Loss: 0.004110035870002182
# Epoch: 60, Batch: 30, Avg. Loss: 0.004111919611667509
# Epoch: 60, Batch: 50, Avg. Loss: 0.004114765410076573
# Epoch: 60, Batch: 70, Avg. Loss: 0.004118726356837496
# Metric on VAL data: 137.14183498121233
# Epoch: 61, Batch: 10, Avg. Loss: 0.004121730005525276
# Epoch: 61, Batch: 30, Avg. Loss: 0.004122612000078645
# Epoch: 61, Batch: 50, Avg. Loss: 0.004125200232538558
# Epoch: 61, Batch: 70, Avg. Loss: 0.004128643155037378
# Metric on VAL data: 142.55292681974012
# Epoch: 62, Batch: 10, Avg. Loss: 0.0041312778942859795
# Epoch: 62, Batch: 30, Avg. Loss: 0.004132709416483298
# Epoch: 62, Batch: 50, Avg. Loss: 0.004136555632833723
# Epoch: 62, Batch: 70, Avg. Loss: 0.004139141173687717
# Metric on VAL data: 136.27683446605863
# Epoch: 63, Batch: 10, Avg. Loss: 0.004140509128513425
# Epoch: 63, Batch: 30, Avg. Loss: 0.004143346791765527
# Epoch: 63, Batch: 50, Avg. Loss: 0.004145240027364775
# Epoch: 63, Batch: 70, Avg. Loss: 0.0041478839478624255
# Metric on VAL data: 137.2715593554232
# Epoch: 64, Batch: 10, Avg. Loss: 0.004151475818181912
# Epoch: 64, Batch: 30, Avg. Loss: 0.004154242408231681
# Epoch: 64, Batch: 50, Avg. Loss: 0.004156810680263526
# Epoch: 64, Batch: 70, Avg. Loss: 0.004158260161452756
# Metric on VAL data: 138.35447619047446
# Epoch: 65, Batch: 10, Avg. Loss: 0.0041599172746645645
# Epoch: 65, Batch: 30, Avg. Loss: 0.004161549229395857
# Epoch: 65, Batch: 50, Avg. Loss: 0.00416348386070327
# Epoch: 65, Batch: 70, Avg. Loss: 0.004167457188563511
# Metric on VAL data: 140.2587807598794
# Epoch: 66, Batch: 10, Avg. Loss: 0.004168533255994993
# Epoch: 66, Batch: 30, Avg. Loss: 0.0041698364936976024
# Epoch: 66, Batch: 50, Avg. Loss: 0.004172425569048194
# Epoch: 66, Batch: 70, Avg. Loss: 0.004175651783970853
# Metric on VAL data: 138.10732791026385
# Epoch: 67, Batch: 10, Avg. Loss: 0.004177576393545485
# Epoch: 67, Batch: 30, Avg. Loss: 0.004179278807182904
# Epoch: 67, Batch: 50, Avg. Loss: 0.004183148136097602
# Epoch: 67, Batch: 70, Avg. Loss: 0.004184531357633592
# Metric on VAL data: 137.52957021263492
# Epoch: 68, Batch: 10, Avg. Loss: 0.00418489663276219
# Epoch: 68, Batch: 30, Avg. Loss: 0.004187578037435308
# Epoch: 68, Batch: 50, Avg. Loss: 0.0041903371039020134
# Epoch: 68, Batch: 70, Avg. Loss: 0.004192047662826394
# Metric on VAL data: 138.69218365173398
# Epoch: 69, Batch: 10, Avg. Loss: 0.0041934820807218815
# Epoch: 69, Batch: 30, Avg. Loss: 0.004196047565902027
# Epoch: 69, Batch: 50, Avg. Loss: 0.004197023157922054
# Epoch: 69, Batch: 70, Avg. Loss: 0.004199330882314361
# Metric on VAL data: 138.23668181618586
# Epoch: 70, Batch: 10, Avg. Loss: 0.004201429358021605
# Epoch: 70, Batch: 30, Avg. Loss: 0.004202862195351624
# Epoch: 70, Batch: 50, Avg. Loss: 0.0042049384318453755
# Epoch: 70, Batch: 70, Avg. Loss: 0.00420768251296434
# Metric on VAL data: 136.8592657965474
# Epoch: 71, Batch: 10, Avg. Loss: 0.004208475442501485
# Epoch: 71, Batch: 30, Avg. Loss: 0.004210921510309918
# Epoch: 71, Batch: 50, Avg. Loss: 0.00421302960557136
# Epoch: 71, Batch: 70, Avg. Loss: 0.004214918246136957
# Metric on VAL data: 137.04794425333102
# Epoch: 72, Batch: 10, Avg. Loss: 0.004217870642700129
# Epoch: 72, Batch: 30, Avg. Loss: 0.0042191442370701805
# Epoch: 72, Batch: 50, Avg. Loss: 0.0042200069312279135
# Epoch: 72, Batch: 70, Avg. Loss: 0.0042216684896557895
# Metric on VAL data: 138.14989461791575
# Epoch: 73, Batch: 10, Avg. Loss: 0.0042229635903816565
# Epoch: 73, Batch: 30, Avg. Loss: 0.0042247208544915135
# Epoch: 73, Batch: 50, Avg. Loss: 0.004226017952097984
# Epoch: 73, Batch: 70, Avg. Loss: 0.004227743609807578
# Metric on VAL data: 134.31459640647083
# Epoch: 74, Batch: 10, Avg. Loss: 0.004231020678372825
# Epoch: 74, Batch: 30, Avg. Loss: 0.004231818449280359
# Epoch: 74, Batch: 50, Avg. Loss: 0.004234009019818027
# Epoch: 74, Batch: 70, Avg. Loss: 0.004235778849950148
# Metric on VAL data: 136.89708695306095
# Finished Training

# %% [markdown]
# ## Display the trained outputs

# %%
num_to_display = 20 
for i in range(num_to_display):
    sample = next(iter(train_loader))
    show_sample_outputs(sample['image'][0:1], sample['keypoints'][0])
# Out:
# index: 0
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 1
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 2
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 3
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 4
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 5
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 6
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 7
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 8
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 9
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 10
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 11
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 12
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 13
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 14
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 15
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 16
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 17
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 18
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])
# index: 19
# image shape: torch.Size([96, 96])
# gt keypoints shape: torch.Size([15, 2])
# predict keypoints shape: torch.Size([15, 2])

# %% [markdown]
# ## Validation on model
# For our experiments, we use mean squared error (MSE) between the ground truth keypoint coordinate vector and the predicted keypoint coordinate vector. Given the ground truth vector and predict vector, MSE loss is defined as the average of the square of all of the error.
#
# #### Notice: the metric in this validation section is the same metric used in test evaluation.  You have to achieve more than 100 to get bonus.

# %%
def VAL_net(model, val_loader):

    model.eval()
    running_loss = 0.0

    # train on batches of data, assumes you already have train_loader
    for batch_i, data in enumerate(val_loader):
        # get the input images and their corresponding labels
        images = data['image']
        key_pts = data['keypoints']

        # flatten pts
        key_pts = key_pts.view(key_pts.size(0), -1)

        # convert variables to floats for regression loss
        key_pts = key_pts.type(torch.FloatTensor)
        images = images.type(torch.FloatTensor)

        # forward pass to get outputs
        output_pts = model(images)

        # calculate the loss between predicted and target keypoints
        loss = criterion(output_pts, key_pts)

        # print loss statistics
        # to convert loss into a scalar and add it to the running_loss, use .item()
        running_loss += loss.item()

    # metric is 1 / (2 * MSE_loss)
    metric = 1.0 / (2 * (running_loss/len(val_loader)))
    print("Metric on VAL data: {}".format(metric))

    # print('Finished Validation')
    model.train()
    return metric

def Evaluate(model):
    # create the validation dataset

    # Google drive path: /content/drive/My Drive/datasets/landmark_data/val.csv
    if path.exists('../datasets/landmark_data/val.csv'):
        VAL_dataset = FacialKeypointsDataset(
                                csv_file='../datasets/landmark_data/val.csv',
                                transform=data_transform)
        # print("VAL_dataset loaded from local")
    else:
        VAL_dataset = FacialKeypointsDataset(
                                csv_file='/content/drive/My Drive/datasets/landmark_data/val.csv',
                                transform=data_transform)
        # print("VAL_dataset loaded from remote")

    val_loader = DataLoader(VAL_dataset, 
                            batch_size=20,
                            shuffle=True, 
                            num_workers=4,
                            drop_last=True,
                        )
    criterion = nn.MSELoss()
    return VAL_net(model, val_loader)

_ = Evaluate(model)

# %% [markdown]
# ## Save the Model
#
# When you are satisfied with your training, save the model for submission.

# %%
model.save("models/keypoints_nn.model")
