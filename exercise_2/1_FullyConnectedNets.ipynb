# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive derivative of loss with respect to outputs and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer and Batch Normalization as a tool to more efficiently optimize deep networks.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cat /proc/cpuinfo
# !nvidia-smi
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !mkdir exercise_code
# !mkdir exercise_code/classifiers

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from exercise_code.classifiers.fc_net import *
from exercise_code.data_utils import get_CIFAR10_data
from exercise_code.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from exercise_code.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# supress cluttering warnings in solutions
import warnings
warnings.filterwarnings('ignore')

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

dir ="content/drive/My Drive/datasets/cifar10"
data = get_CIFAR10_data(path=dir)
for k, v in data.items():
    print('%s: ' % k, v.shape)
# Out:
# cifar10 path: /content/drive/My Drive/datasets/cifar10
# X_train:  (48000, 3, 32, 32)
# y_train:  (48000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# # Affine layer: foward
# Open the file `exercise_code/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around 1e-9.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function

x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around 1e-10
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  1.0497686790701145e-09
# dw error:  2.234997277242093e-09
# db error:  5.448729860809688e-10

# %% [markdown]
# # ReLU layer: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be around 1e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU layer: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be around 1e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2755809009665906e-12

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `exercise_code/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from exercise_code.layer_utils import affine_relu_forward, affine_relu_backward

x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

print('Testing affine_relu_forward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward:
# dx error:  3.585825904137967e-11
# dw error:  8.206885408453043e-10
# db error:  7.826654027483749e-12

# %% [markdown]
# # Loss layers: Softmax
# You implemented this loss function in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `exercise_code/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be 2.3 and dx error should be 1e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3025237109136483
# dx error:  7.843260876331618e-09

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `exercise_code/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-2
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-8, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-8, 'Problem with regularization loss'

for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)
  assert grads != {}, 'Problem with gradients (empty dict)'

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss
# Running numeric gradient check with reg =  0.0
# W1 relative error: 2.44e-08
# W2 relative error: 1.20e-08
# b1 relative error: 1.38e-08
# b2 relative error: 1.09e-08
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 7.86e-07
# b1 relative error: 1.56e-08
# b2 relative error: 1.06e-08

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `exercise_code/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet(hidden_dim=150, reg=1e-3, weight_scale=1e-3)
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
solver = Solver(model, data, 
                update_rule='sgd',
                optim_config={'learning_rate':1e-3},
                lr_decay=0.95,
                batch_size=256,
                num_epochs=10,
                print_every=100)
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 1870) loss: 2.307652
# (Epoch 0 / 10) train acc: 0.109000; val_acc: 0.104000
# (Iteration 101 / 1870) loss: 1.807686
# (Epoch 1 / 10) train acc: 0.424000; val_acc: 0.403000
# (Iteration 201 / 1870) loss: 1.635552
# (Iteration 301 / 1870) loss: 1.539284
# (Epoch 2 / 10) train acc: 0.442000; val_acc: 0.446000
# (Iteration 401 / 1870) loss: 1.640920
# (Iteration 501 / 1870) loss: 1.459951
# (Epoch 3 / 10) train acc: 0.482000; val_acc: 0.488000
# (Iteration 601 / 1870) loss: 1.415573
# (Iteration 701 / 1870) loss: 1.345653
# (Epoch 4 / 10) train acc: 0.516000; val_acc: 0.482000
# (Iteration 801 / 1870) loss: 1.372661
# (Iteration 901 / 1870) loss: 1.393459
# (Epoch 5 / 10) train acc: 0.529000; val_acc: 0.495000
# (Iteration 1001 / 1870) loss: 1.409050
# (Iteration 1101 / 1870) loss: 1.357380
# (Epoch 6 / 10) train acc: 0.524000; val_acc: 0.495000
# (Iteration 1201 / 1870) loss: 1.233469
# (Iteration 1301 / 1870) loss: 1.250516
# (Epoch 7 / 10) train acc: 0.556000; val_acc: 0.516000
# (Iteration 1401 / 1870) loss: 1.313225
# (Epoch 8 / 10) train acc: 0.587000; val_acc: 0.494000
# (Iteration 1501 / 1870) loss: 1.197658
# (Iteration 1601 / 1870) loss: 1.143183
# (Epoch 9 / 10) train acc: 0.544000; val_acc: 0.502000
# (Iteration 1701 / 1870) loss: 1.250253
# (Iteration 1801 / 1870) loss: 1.183748
# (Epoch 10 / 10) train acc: 0.610000; val_acc: 0.510000

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `exercise_code/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing batch normalization.

# %% [markdown]
# ## Initial loss and gradient check

# %% [markdown]
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-6 or less.

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.306248636344961
# W1 relative error: 2.84e-07
# W2 relative error: 1.05e-06
# W3 relative error: 7.35e-08
# b1 relative error: 3.16e-08
# b2 relative error: 8.02e-09
# b3 relative error: 6.16e-10
# Running check with reg =  3.14
# Initial loss:  6.981686258963524
# W1 relative error: 3.48e-08
# W2 relative error: 2.27e-08
# W3 relative error: 3.60e-08
# b1 relative error: 5.63e-08
# b2 relative error: 3.88e-09
# b3 relative error: 6.23e-10

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. You will need to tweak the learning rate and initialization scale, but you should be able to overfit and achieve 100% **training** accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

#############################################################################
# TODO: Maybe tweak values                                                  #
#############################################################################
weight_scale = 2e-2
learning_rate = 1e-2

model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.865895
# (Epoch 0 / 20) train acc: 0.280000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.101000
# (Epoch 2 / 20) train acc: 0.640000; val_acc: 0.153000
# (Epoch 3 / 20) train acc: 0.680000; val_acc: 0.156000
# (Epoch 4 / 20) train acc: 0.760000; val_acc: 0.147000
# (Epoch 5 / 20) train acc: 0.840000; val_acc: 0.161000
# (Iteration 11 / 40) loss: 0.728284
# (Epoch 6 / 20) train acc: 0.940000; val_acc: 0.172000
# (Epoch 7 / 20) train acc: 0.960000; val_acc: 0.160000
# (Epoch 8 / 20) train acc: 0.980000; val_acc: 0.168000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.160000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.153000
# (Iteration 21 / 40) loss: 0.092186
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.154000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.160000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.162000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.158000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.157000
# (Iteration 31 / 40) loss: 0.033689
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.163000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.160000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.160000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.162000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.160000

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

#############################################################################
# TODO: Maybe tweak values                                                  #
#############################################################################
learning_rate = 1e-2
weight_scale = 5e-2
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################

#####################################################################################

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 4.171202
# (Epoch 0 / 20) train acc: 0.320000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.260000; val_acc: 0.111000
# (Epoch 2 / 20) train acc: 0.360000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.740000; val_acc: 0.143000
# (Epoch 4 / 20) train acc: 0.820000; val_acc: 0.140000
# (Epoch 5 / 20) train acc: 0.880000; val_acc: 0.157000
# (Iteration 11 / 40) loss: 0.630705
# (Epoch 6 / 20) train acc: 0.940000; val_acc: 0.152000
# (Epoch 7 / 20) train acc: 1.000000; val_acc: 0.150000
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.149000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.146000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.149000
# (Iteration 21 / 40) loss: 0.195732
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.154000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.153000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.150000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.149000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.149000
# (Iteration 31 / 40) loss: 0.057964
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.148000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.150000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.149000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.148000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.148000

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net?</p>
# </div>

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochstic gradient descent.
#
# Open the file `exercise_code/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than 1e-8.

# %%
from exercise_code.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('running with ', update_rule)
    model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=3e-2)

    solver = Solver(model, small_data,
                    num_epochs=10, batch_size=100,
                    update_rule=update_rule,
                    optim_config={'learning_rate': 1e-2},
                    verbose=True)
    solvers[update_rule] = solver
    solver.train()
    print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
    plt.subplot(3, 1, 1)
    plt.plot(solver.loss_history, 'o', label=update_rule)
  
    plt.subplot(3, 1, 2)
    plt.plot(solver.train_acc_history, '-o', label=update_rule)

    plt.subplot(3, 1, 3)
    plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
    plt.subplot(3, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 400) loss: 2.304167
# (Epoch 0 / 10) train acc: 0.095000; val_acc: 0.104000
# (Iteration 11 / 400) loss: 2.300510
# (Iteration 21 / 400) loss: 2.303528
# (Iteration 31 / 400) loss: 2.288235
# (Epoch 1 / 10) train acc: 0.142000; val_acc: 0.155000
# (Iteration 41 / 400) loss: 2.291822
# (Iteration 51 / 400) loss: 2.290192
# (Iteration 61 / 400) loss: 2.288800
# (Iteration 71 / 400) loss: 2.288602
# (Epoch 2 / 10) train acc: 0.155000; val_acc: 0.157000
# (Iteration 81 / 400) loss: 2.272034
# (Iteration 91 / 400) loss: 2.260004
# (Iteration 101 / 400) loss: 2.263298
# (Iteration 111 / 400) loss: 2.243412
# (Epoch 3 / 10) train acc: 0.145000; val_acc: 0.133000
# (Iteration 121 / 400) loss: 2.235999
# (Iteration 131 / 400) loss: 2.216616
# (Iteration 141 / 400) loss: 2.184902
# (Iteration 151 / 400) loss: 2.179164
# (Epoch 4 / 10) train acc: 0.230000; val_acc: 0.205000
# (Iteration 161 / 400) loss: 2.143888
# (Iteration 171 / 400) loss: 2.155074
# (Iteration 181 / 400) loss: 2.124487
# (Iteration 191 / 400) loss: 2.100365
# (Epoch 5 / 10) train acc: 0.270000; val_acc: 0.246000
# (Iteration 201 / 400) loss: 2.003501
# (Iteration 211 / 400) loss: 2.063189
# (Iteration 221 / 400) loss: 1.956031
# (Iteration 231 / 400) loss: 1.846253
# (Epoch 6 / 10) train acc: 0.305000; val_acc: 0.248000
# (Iteration 241 / 400) loss: 2.036603
# (Iteration 251 / 400) loss: 1.949184
# (Iteration 261 / 400) loss: 1.900342
# (Iteration 271 / 400) loss: 1.915909
# (Epoch 7 / 10) train acc: 0.335000; val_acc: 0.271000
# (Iteration 281 / 400) loss: 1.946809
# (Iteration 291 / 400) loss: 1.986195
# (Iteration 301 / 400) loss: 1.890429
# (Iteration 311 / 400) loss: 1.930284
# (Epoch 8 / 10) train acc: 0.299000; val_acc: 0.284000
# (Iteration 321 / 400) loss: 2.024478
# (Iteration 331 / 400) loss: 1.759896
# (Iteration 341 / 400) loss: 1.760075
# (Iteration 351 / 400) loss: 1.799764
# (Epoch 9 / 10) train acc: 0.390000; val_acc: 0.300000
# (Iteration 361 / 400) loss: 1.856113
# (Iteration 371 / 400) loss: 1.806241
# (Iteration 381 / 400) loss: 1.830494
# (Iteration 391 / 400) loss: 1.765807
# (Epoch 10 / 10) train acc: 0.370000; val_acc: 0.310000
#
# running with  sgd_momentum
# (Iteration 1 / 400) loss: 2.304688
# (Epoch 0 / 10) train acc: 0.090000; val_acc: 0.082000
# (Iteration 11 / 400) loss: 2.288526
# (Iteration 21 / 400) loss: 2.268510
# (Iteration 31 / 400) loss: 2.180694
# (Epoch 1 / 10) train acc: 0.196000; val_acc: 0.166000
# (Iteration 41 / 400) loss: 2.071960
# (Iteration 51 / 400) loss: 1.896338
# (Iteration 61 / 400) loss: 1.920502
# (Iteration 71 / 400) loss: 1.913988
# (Epoch 2 / 10) train acc: 0.308000; val_acc: 0.288000
# (Iteration 81 / 400) loss: 1.873563
# (Iteration 91 / 400) loss: 1.861424
# (Iteration 101 / 400) loss: 1.676081
# (Iteration 111 / 400) loss: 1.751884
# (Epoch 3 / 10) train acc: 0.374000; val_acc: 0.333000
# (Iteration 121 / 400) loss: 1.666268
# (Iteration 131 / 400) loss: 1.858792
# (Iteration 141 / 400) loss: 1.488131
# (Iteration 151 / 400) loss: 1.527094
# (Epoch 4 / 10) train acc: 0.421000; val_acc: 0.349000
# (Iteration 161 / 400) loss: 1.593093
# (Iteration 171 / 400) loss: 1.598328
# (Iteration 181 / 400) loss: 1.560593
# (Iteration 191 / 400) loss: 1.459218
# (Epoch 5 / 10) train acc: 0.420000; val_acc: 0.329000
# (Iteration 201 / 400) loss: 1.546723
# (Iteration 211 / 400) loss: 1.423782
# (Iteration 221 / 400) loss: 1.318687
# (Iteration 231 / 400) loss: 1.518831
# (Epoch 6 / 10) train acc: 0.478000; val_acc: 0.365000
# (Iteration 241 / 400) loss: 1.443258
# (Iteration 251 / 400) loss: 1.431308
# (Iteration 261 / 400) loss: 1.532624
# (Iteration 271 / 400) loss: 1.305318
# (Epoch 7 / 10) train acc: 0.497000; val_acc: 0.354000
# (Iteration 281 / 400) loss: 1.348540
# (Iteration 291 / 400) loss: 1.403374
# (Iteration 301 / 400) loss: 1.241911
# (Iteration 311 / 400) loss: 1.244225
# (Epoch 8 / 10) train acc: 0.506000; val_acc: 0.359000
# (Iteration 321 / 400) loss: 1.371899
# (Iteration 331 / 400) loss: 1.219907
# (Iteration 341 / 400) loss: 1.172212
# (Iteration 351 / 400) loss: 1.052598
# (Epoch 9 / 10) train acc: 0.553000; val_acc: 0.359000
# (Iteration 361 / 400) loss: 1.357706
# (Iteration 371 / 400) loss: 1.143316
# (Iteration 381 / 400) loss: 1.188007
# (Iteration 391 / 400) loss: 1.169808
# (Epoch 10 / 10) train acc: 0.593000; val_acc: 0.352000

# %% [markdown]
# # Adam
# Adam [1] is an update rule that sets per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `exercise_code/optim.py`, we have implemented the update rule `adam` for you. Check this implementation and make sure you understand what the optimizer is doing. Then train the fully connected net below to see how Adam affects the learning process.
#
# [1] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
learning_rates = {'adam': 1e-3}
update_rule = 'adam'
print('running with ', update_rule)
model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

solver = Solver(model, small_data,
              num_epochs=5, batch_size=100,
              update_rule=update_rule,
              optim_config={
                'learning_rate': learning_rates[update_rule]
              },
              verbose=True)
solvers[update_rule] = solver
solver.train()
print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
    plt.subplot(3, 1, 1)
    plt.plot(solver.loss_history, 'o', label=update_rule)
  
    plt.subplot(3, 1, 2)
    plt.plot(solver.train_acc_history, '-o', label=update_rule)

    plt.subplot(3, 1, 3)
    plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
    plt.subplot(3, 1, i)
    plt.legend(loc='upper center', ncol=4)
    
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  adam
# (Iteration 1 / 200) loss: 2.664491
# (Epoch 0 / 5) train acc: 0.139000; val_acc: 0.104000
# (Iteration 11 / 200) loss: 2.018875
# (Iteration 21 / 200) loss: 1.801580
# (Iteration 31 / 200) loss: 1.705937
# (Epoch 1 / 5) train acc: 0.333000; val_acc: 0.270000
# (Iteration 41 / 200) loss: 1.834502
# (Iteration 51 / 200) loss: 1.658236
# (Iteration 61 / 200) loss: 1.905742
# (Iteration 71 / 200) loss: 1.518596
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.342000
# (Iteration 81 / 200) loss: 1.917596
# (Iteration 91 / 200) loss: 1.591769
# (Iteration 101 / 200) loss: 1.491899
# (Iteration 111 / 200) loss: 1.538055
# (Epoch 3 / 5) train acc: 0.441000; val_acc: 0.347000
# (Iteration 121 / 200) loss: 1.440636
# (Iteration 131 / 200) loss: 1.423734
# (Iteration 141 / 200) loss: 1.303681
# (Iteration 151 / 200) loss: 1.173172
# (Epoch 4 / 5) train acc: 0.533000; val_acc: 0.354000
# (Iteration 161 / 200) loss: 1.285883
# (Iteration 171 / 200) loss: 1.316111
# (Iteration 181 / 200) loss: 1.262382
# (Iteration 191 / 200) loss: 1.125899
# (Epoch 5 / 5) train acc: 0.565000; val_acc: 0.346000

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least __50%__ accuracy on the validation set using a fully-connected net.
#
# You might find it useful to complete the `2_BatchNormalization.ipynb` and the `3_Dropout.ipynb` notebooks before completing this part, since these techniques can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# batch normalization and dropout useful. Store your best model in the         #
# best_model variable.                                                         #
# Note that dropout is not required to pass beyond the linear scoring regime   #
################################################################################
best_acc = 0
best_params = []

# Grid search over learning_rate, learning_rate_decay, weight_scale
lr_range = np.arange(0.5e-3, 5e-3, 0.5e-3)
lr_decay_range = np.array([0.8, 0.85, 0.9, 0.95])
weight_scale_range = np.arange(1e-2, 10e-2, 1.5e-2)

# Setting up the main training loop
total_iterations = (lr_range.shape[0] * lr_decay_range.shape[0] * 
                    weight_scale_range.shape[0])
iteration = 0

for lr in lr_range:
    for lr_decay in lr_decay_range:
        for weight_scale in weight_scale_range:
            iteration += 1
            print()
            print(f'Starting iteration: {iteration} / {total_iterations}')
            print(f'    lr: {lr}\n    lr_decay: {lr_decay}' + 
                  f'\n    weight_scale: {weight_scale}')
            
            # FullyConnectedNet
            # 5 times 128 hidden nodes
            # NO batchnorm (until now)
            # NO dropout (until now)
            model = FullyConnectedNet([100, 100, 100, 100, 100], 
                                      weight_scale=weight_scale, 
                                      use_batchnorm=False, 
                                      dropout=0)
            # Solver
            # update = adam
            # 15 epochs
            # 256 batch size
            solver = Solver(model,
                            data,
                            update_rule = 'adam',
                            optim_config = {'learning_rate':lr},
                            lr_decay = lr_decay,
                            num_epochs = 10,
                            batch_size = 256,
                            print_every = 100,
                            verbose = False
                           )
            
            solver.train()
            val_acc = solver.check_accuracy(data['X_val'], data['y_val'])
            print(f'Validation accuracy: {val_acc*100}%')
            if val_acc>best_acc:
                # If new best:
                # Store params and plot loss and accuracy
                best_acc = val_acc
                best_model = model
                best_params = [lr, lr_decay, weight_scale]
                
                plt.subplot(2, 1, 1)
                plt.title('Training loss')
                plt.plot(solver.loss_history, 'o')
                plt.xlabel('Iteration')

                plt.subplot(2, 1, 2)
                plt.title('Accuracy')
                plt.plot(solver.train_acc_history, '-o', label='train')
                plt.plot(solver.val_acc_history, '-o', label='val')
                plt.plot([0.5] * len(solver.val_acc_history), 'k--')
                plt.xlabel('Epoch')
                plt.legend(loc='lower right')
                plt.gcf().set_size_inches(15, 12)
                plt.show()

print("best_acc = ", best_acc)
print("best_params = ", best_params)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Starting iteration: 1 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 50.6%
# Starting iteration: 2 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 54.6%
# Starting iteration: 3 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 51.5%
#
# Starting iteration: 4 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.800000000000004%
#
# Starting iteration: 5 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 45.6%
#
# Starting iteration: 6 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 40.2%
#
# Starting iteration: 7 / 252
#     lr: 0.0005
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 29.7%
#
# Starting iteration: 8 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 9 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 52.6%
#
# Starting iteration: 10 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 52.1%
#
# Starting iteration: 11 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 48.699999999999996%
#
# Starting iteration: 12 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 46.0%
#
# Starting iteration: 13 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 39.4%
#
# Starting iteration: 14 / 252
#     lr: 0.0005
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 36.4%
#
# Starting iteration: 15 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 50.3%
#
# Starting iteration: 16 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 51.1%
#
# Starting iteration: 17 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.5%
#
# Starting iteration: 18 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 50.5%
#
# Starting iteration: 19 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 46.1%
#
# Starting iteration: 20 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 44.5%
#
# Starting iteration: 21 / 252
#     lr: 0.0005
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 35.9%
#
# Starting iteration: 22 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 51.4%
#
# Starting iteration: 23 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 51.800000000000004%
#
# Starting iteration: 24 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 52.5%
#
# Starting iteration: 25 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 49.6%
#
# Starting iteration: 26 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 45.2%
#
# Starting iteration: 27 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 41.3%
#
# Starting iteration: 28 / 252
#     lr: 0.0005
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 40.300000000000004%
#
# Starting iteration: 29 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 30 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 53.6%
#
# Starting iteration: 31 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 52.900000000000006%
#
# Starting iteration: 32 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 50.0%
#
# Starting iteration: 33 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 46.7%
#
# Starting iteration: 34 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 44.2%
#
# Starting iteration: 35 / 252
#     lr: 0.001
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 42.4%
#
# Starting iteration: 36 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 52.6%
#
# Starting iteration: 37 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 54.400000000000006%
#
# Starting iteration: 38 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 51.6%
#
# Starting iteration: 39 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.0%
#
# Starting iteration: 40 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 47.5%
#
# Starting iteration: 41 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 45.300000000000004%
#
# Starting iteration: 42 / 252
#     lr: 0.001
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 42.3%
#
# Starting iteration: 43 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 52.5%
#
# Starting iteration: 44 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 54.1%
#
# Starting iteration: 45 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 53.6%
#
# Starting iteration: 46 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 50.9%
#
# Starting iteration: 47 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 48.699999999999996%
#
# Starting iteration: 48 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 46.2%
#
# Starting iteration: 49 / 252
#     lr: 0.001
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 41.0%
#
# Starting iteration: 50 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 52.1%
#
# Starting iteration: 51 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 51.6%
#
# Starting iteration: 52 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 51.6%
#
# Starting iteration: 53 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.1%
#
# Starting iteration: 54 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 48.8%
#
# Starting iteration: 55 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 46.2%
#
# Starting iteration: 56 / 252
#     lr: 0.001
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 42.3%
#
# Starting iteration: 57 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 52.0%
#
# Starting iteration: 58 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 53.7%
#
# Starting iteration: 59 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 52.900000000000006%
#
# Starting iteration: 60 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 53.1%
#
# Starting iteration: 61 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 51.5%
#
# Starting iteration: 62 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 45.4%
#
# Starting iteration: 63 / 252
#     lr: 0.0015
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 41.5%
#
# Starting iteration: 64 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 52.400000000000006%
#
# Starting iteration: 65 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 53.2%
#
# Starting iteration: 66 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 52.900000000000006%
#
# Starting iteration: 67 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.0%
#
# Starting iteration: 68 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 48.9%
#
# Starting iteration: 69 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 45.7%
#
# Starting iteration: 70 / 252
#     lr: 0.0015
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 42.199999999999996%
#
# Starting iteration: 71 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 53.400000000000006%
#
# Starting iteration: 72 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 52.6%
#
# Starting iteration: 73 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.6%
#
# Starting iteration: 74 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 75 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 50.0%
#
# Starting iteration: 76 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 46.6%
#
# Starting iteration: 77 / 252
#     lr: 0.0015
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 42.6%
#
# Starting iteration: 78 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 79 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 80 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 81 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.9%
#
# Starting iteration: 82 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 49.7%
#
# Starting iteration: 83 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 47.9%
#
# Starting iteration: 84 / 252
#     lr: 0.0015
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 44.5%
#
# Starting iteration: 85 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 52.900000000000006%
#
# Starting iteration: 86 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 55.300000000000004%
# Starting iteration: 87 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 52.0%
#
# Starting iteration: 88 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.800000000000004%
#
# Starting iteration: 89 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 51.0%
#
# Starting iteration: 90 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 49.3%
#
# Starting iteration: 91 / 252
#     lr: 0.002
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 42.6%
#
# Starting iteration: 92 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 53.6%
#
# Starting iteration: 93 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 54.7%
#
# Starting iteration: 94 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 51.6%
#
# Starting iteration: 95 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 53.5%
#
# Starting iteration: 96 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.2%
#
# Starting iteration: 97 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 46.1%
#
# Starting iteration: 98 / 252
#     lr: 0.002
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 44.3%
#
# Starting iteration: 99 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 50.6%
#
# Starting iteration: 100 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 51.800000000000004%
#
# Starting iteration: 101 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 51.6%
#
# Starting iteration: 102 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.7%
#
# Starting iteration: 103 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 49.3%
#
# Starting iteration: 104 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 48.1%
#
# Starting iteration: 105 / 252
#     lr: 0.002
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 45.5%
#
# Starting iteration: 106 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 50.7%
#
# Starting iteration: 107 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 52.800000000000004%
#
# Starting iteration: 108 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 51.800000000000004%
#
# Starting iteration: 109 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.0%
#
# Starting iteration: 110 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 50.7%
#
# Starting iteration: 111 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 48.4%
#
# Starting iteration: 112 / 252
#     lr: 0.002
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 45.9%
#
# Starting iteration: 113 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 114 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 52.800000000000004%
#
# Starting iteration: 115 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 52.5%
#
# Starting iteration: 116 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.0%
#
# Starting iteration: 117 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 52.0%
#
# Starting iteration: 118 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 46.300000000000004%
#
# Starting iteration: 119 / 252
#     lr: 0.0025
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 44.4%
#
# Starting iteration: 120 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 52.1%
#
# Starting iteration: 121 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 122 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 53.2%
#
# Starting iteration: 123 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.6%
#
# Starting iteration: 124 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.7%
#
# Starting iteration: 125 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 48.9%
#
# Starting iteration: 126 / 252
#     lr: 0.0025
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 44.4%
#
# Starting iteration: 127 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 50.1%
#
# Starting iteration: 128 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 50.6%
#
# Starting iteration: 129 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 53.0%
#
# Starting iteration: 130 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 131 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 49.5%
#
# Starting iteration: 132 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 49.1%
#
# Starting iteration: 133 / 252
#     lr: 0.0025
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 43.1%
#
# Starting iteration: 134 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 51.2%
#
# Starting iteration: 135 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 51.6%
#
# Starting iteration: 136 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 51.9%
#
# Starting iteration: 137 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.1%
#
# Starting iteration: 138 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 48.9%
#
# Starting iteration: 139 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 49.7%
#
# Starting iteration: 140 / 252
#     lr: 0.0025
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 45.0%
#
# Starting iteration: 141 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 142 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 51.800000000000004%
#
# Starting iteration: 143 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 51.4%
#
# Starting iteration: 144 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.0%
#
# Starting iteration: 145 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 50.7%
#
# Starting iteration: 146 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 48.0%
#
# Starting iteration: 147 / 252
#     lr: 0.003
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 44.1%
#
# Starting iteration: 148 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 149 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 51.6%
#
# Starting iteration: 150 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 51.9%
#
# Starting iteration: 151 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 152 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.0%
#
# Starting iteration: 153 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 48.4%
#
# Starting iteration: 154 / 252
#     lr: 0.003
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 44.1%
#
# Starting iteration: 155 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 50.1%
#
# Starting iteration: 156 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 53.400000000000006%
#
# Starting iteration: 157 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 158 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.900000000000006%
#
# Starting iteration: 159 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 51.2%
#
# Starting iteration: 160 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 47.8%
#
# Starting iteration: 161 / 252
#     lr: 0.003
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 44.6%
#
# Starting iteration: 162 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 51.2%
#
# Starting iteration: 163 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 53.300000000000004%
#
# Starting iteration: 164 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 51.5%
#
# Starting iteration: 165 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.5%
#
# Starting iteration: 166 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 50.3%
#
# Starting iteration: 167 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 48.9%
#
# Starting iteration: 168 / 252
#     lr: 0.003
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 46.800000000000004%
#
# Starting iteration: 169 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 51.9%
#
# Starting iteration: 170 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 52.300000000000004%
#
# Starting iteration: 171 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 51.9%
#
# Starting iteration: 172 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.5%
#
# Starting iteration: 173 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 50.4%
#
# Starting iteration: 174 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 48.5%
#
# Starting iteration: 175 / 252
#     lr: 0.0035
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 43.0%
#
# Starting iteration: 176 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 51.0%
#
# Starting iteration: 177 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 52.1%
#
# Starting iteration: 178 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 51.9%
#
# Starting iteration: 179 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.0%
#
# Starting iteration: 180 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.1%
#
# Starting iteration: 181 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 50.0%
#
# Starting iteration: 182 / 252
#     lr: 0.0035
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 45.1%
#
# Starting iteration: 183 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 49.1%
#
# Starting iteration: 184 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 51.5%
#
# Starting iteration: 185 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.6%
#
# Starting iteration: 186 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.2%
#
# Starting iteration: 187 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 50.5%
#
# Starting iteration: 188 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 48.8%
#
# Starting iteration: 189 / 252
#     lr: 0.0035
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 47.5%
#
# Starting iteration: 190 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 49.4%
#
# Starting iteration: 191 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 51.6%
#
# Starting iteration: 192 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 50.4%
#
# Starting iteration: 193 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 50.1%
#
# Starting iteration: 194 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 49.5%
#
# Starting iteration: 195 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 50.2%
#
# Starting iteration: 196 / 252
#     lr: 0.0035
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 47.9%
#
# Starting iteration: 197 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 50.6%
#
# Starting iteration: 198 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 51.9%
#
# Starting iteration: 199 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 52.2%
#
# Starting iteration: 200 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.9%
#
# Starting iteration: 201 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 51.1%
#
# Starting iteration: 202 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 47.599999999999994%
#
# Starting iteration: 203 / 252
#     lr: 0.004
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 42.8%
#
# Starting iteration: 204 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 49.2%
#
# Starting iteration: 205 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 206 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 51.9%
#
# Starting iteration: 207 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 52.1%
#
# Starting iteration: 208 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.0%
#
# Starting iteration: 209 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 49.2%
#
# Starting iteration: 210 / 252
#     lr: 0.004
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 46.400000000000006%
#
# Starting iteration: 211 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 51.7%
#
# Starting iteration: 212 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 52.2%
#
# Starting iteration: 213 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.5%
#
# Starting iteration: 214 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.2%
#
# Starting iteration: 215 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 51.5%
#
# Starting iteration: 216 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 49.6%
#
# Starting iteration: 217 / 252
#     lr: 0.004
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 45.7%
#
# Starting iteration: 218 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 48.5%
#
# Starting iteration: 219 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 50.2%
#
# Starting iteration: 220 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 51.7%
#
# Starting iteration: 221 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 48.8%
#
# Starting iteration: 222 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 51.9%
#
# Starting iteration: 223 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 49.3%
#
# Starting iteration: 224 / 252
#     lr: 0.004
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 47.5%
#
# Starting iteration: 225 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.01
# Validation accuracy: 50.6%
#
# Starting iteration: 226 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.025
# Validation accuracy: 50.4%
#
# Starting iteration: 227 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.04
# Validation accuracy: 53.6%
#
# Starting iteration: 228 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 229 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.07
# Validation accuracy: 51.5%
#
# Starting iteration: 230 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.085
# Validation accuracy: 48.3%
#
# Starting iteration: 231 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.8
#     weight_scale: 0.1
# Validation accuracy: 44.0%
#
# Starting iteration: 232 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.01
# Validation accuracy: 51.7%
#
# Starting iteration: 233 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.025
# Validation accuracy: 50.4%
#
# Starting iteration: 234 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.04
# Validation accuracy: 50.3%
#
# Starting iteration: 235 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.05500000000000001
# Validation accuracy: 50.8%
#
# Starting iteration: 236 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.07
# Validation accuracy: 50.3%
#
# Starting iteration: 237 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.085
# Validation accuracy: 50.1%
#
# Starting iteration: 238 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.85
#     weight_scale: 0.1
# Validation accuracy: 42.199999999999996%
#
# Starting iteration: 239 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.01
# Validation accuracy: 47.699999999999996%
#
# Starting iteration: 240 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.025
# Validation accuracy: 51.0%
#
# Starting iteration: 241 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.04
# Validation accuracy: 52.5%
#
# Starting iteration: 242 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.05500000000000001
# Validation accuracy: 51.300000000000004%
#
# Starting iteration: 243 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.07
# Validation accuracy: 50.6%
#
# Starting iteration: 244 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.085
# Validation accuracy: 49.3%
#
# Starting iteration: 245 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.9
#     weight_scale: 0.1
# Validation accuracy: 44.4%
#
# Starting iteration: 246 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.01
# Validation accuracy: 47.8%
#
# Starting iteration: 247 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.025
# Validation accuracy: 49.9%
#
# Starting iteration: 248 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.04
# Validation accuracy: 48.199999999999996%
#
# Starting iteration: 249 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.05500000000000001
# Validation accuracy: 48.5%
#
# Starting iteration: 250 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.07
# Validation accuracy: 49.6%
#
# Starting iteration: 251 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.085
# Validation accuracy: 48.699999999999996%
#
# Starting iteration: 252 / 252
#     lr: 0.0045000000000000005
#     lr_decay: 0.95
#     weight_scale: 0.1
# Validation accuracy: 45.800000000000004%
# best_acc =  0.553
# best_params =  [0.002, 0.8, 0.025]

# %% [markdown]
# # Test your model
# Run your best model on the validation and test sets. You should achieve score of above __50%__ accuracy on the validation set.

# %%
X_test = data['X_test']
X_val = data['X_val']
y_val = data['y_val']
y_test = data['y_test']

y_test_pred = np.argmax(best_model.loss(X_test), axis=1)
y_val_pred = np.argmax(best_model.loss(X_val), axis=1)
print('Validation set accuracy: ', (y_val_pred == y_val).mean())
print('Test set accuracy: ', (y_test_pred == y_test).mean())
# Out:
# Validation set accuracy:  0.553
# Test set accuracy:  0.531

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.

# %% [markdown]
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>You might get an error like this:</p>
#     <p>PicklingError: Can't pickle <class 'exercise_code.classifiers.softmax.SoftmaxClassifier'>: it's not the same object as exercise_code.classifiers.softmax.SoftmaxClassifier</p>
#     <p>The reason is that we are using autoreload and working on this class during the notebook session. If you get this error simply restart the kernel and rerun the whole script (Kernel -> Restart & Run All) or only the important cells for generating your model.</p>
# </div>

# %%
from exercise_code.model_savers import save_fully_connected_net
save_fully_connected_net(best_model)
