# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir exercise_code
# !mkdir exercise_code/classifiers

# %%
# A bit of setup
import numpy as np
import matplotlib.pyplot as plt

from exercise_code.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `exercise_code/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.
input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `exercise_code/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the Softmax exercise: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs. Please first read the class description in the file, in particular note that for this exercise we use ReLU non-linearities.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from exercise_code.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# W2 max relative error: 3.440708e-09
# b1 max relative error: 2.738421e-09
# b2 max relative error: 4.447625e-11

# %% [markdown]
# # Train a Toy Network
# To train the network we will use stochastic gradient descent (SGD), similar to the Softmax classifier. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the Softmax classifier. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss of less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732093

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from exercise_code.data_utils import load_CIFAR10
from exercise_code.vis_utils import visualize_cifar10

def get_CIFAR10_data(num_training=48000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. 
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = '/content/drive/My Drive/datasets/cifar10/'
    X, y = load_CIFAR10(cifar10_dir)

    # Our training set will be the first num_train points from the original
    # dataset.
    mask = range(num_training)
    X_train = X[mask]
    y_train = y[mask]
    
    # Our validation set will be num_validation points from the original
    # dataset.
    mask = range(num_training, num_training + num_validation)
    X_val = X[mask]
    y_val = y[mask]
    
    # We use a small subset of the dataset as our test set.
    mask = range(num_training + num_validation, num_training + num_validation + num_test)
    X_test = X[mask]
    y_test = y[mask]
    
    # We will also make a development set, which is a small subset of
    # the training set. This way the development cycle is faster.
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

    return X, y, X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_raw, y_raw, X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)

# visualize raw data
visualize_cifar10(X_raw, y_raw)
# Out:
# Train data shape:  (48000, 3072)
# Train labels shape:  (48000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)

# %% [markdown]
# # Train a Network
# As before, we will use SGD to train our network. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=5000, batch_size=200,
            learning_rate=1e-3, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 5000: loss 2.302997
# iteration 100 / 5000: loss 1.893410
# iteration 200 / 5000: loss 1.890001
# iteration 300 / 5000: loss 1.672805
# iteration 400 / 5000: loss 1.663876
# iteration 500 / 5000: loss 1.497780
# iteration 600 / 5000: loss 1.416839
# iteration 700 / 5000: loss 1.594046
# iteration 800 / 5000: loss 1.491366
# iteration 900 / 5000: loss 1.391435
# iteration 1000 / 5000: loss 1.388317
# iteration 1100 / 5000: loss 1.620964
# iteration 1200 / 5000: loss 1.400283
# iteration 1300 / 5000: loss 1.606481
# iteration 1400 / 5000: loss 1.455534
# iteration 1500 / 5000: loss 1.355058
# iteration 1600 / 5000: loss 1.387846
# iteration 1700 / 5000: loss 1.360737
# iteration 1800 / 5000: loss 1.360486
# iteration 1900 / 5000: loss 1.574591
# iteration 2000 / 5000: loss 1.574502
# iteration 2100 / 5000: loss 1.436698
# iteration 2200 / 5000: loss 1.333643
# iteration 2300 / 5000: loss 1.522015
# iteration 2400 / 5000: loss 1.389753
# iteration 2500 / 5000: loss 1.375743
# iteration 2600 / 5000: loss 1.364093
# iteration 2700 / 5000: loss 1.491677
# iteration 2800 / 5000: loss 1.351030
# iteration 2900 / 5000: loss 1.473865
# iteration 3000 / 5000: loss 1.373931
# iteration 3100 / 5000: loss 1.544761
# iteration 3200 / 5000: loss 1.317276
# iteration 3300 / 5000: loss 1.213024
# iteration 3400 / 5000: loss 1.480623
# iteration 3500 / 5000: loss 1.397637
# iteration 3600 / 5000: loss 1.397284
# iteration 3700 / 5000: loss 1.403290
# iteration 3800 / 5000: loss 1.448629
# iteration 3900 / 5000: loss 1.286507
# iteration 4000 / 5000: loss 1.338852
# iteration 4100 / 5000: loss 1.242296
# iteration 4200 / 5000: loss 1.351498
# iteration 4300 / 5000: loss 1.338838
# iteration 4400 / 5000: loss 1.344772
# iteration 4500 / 5000: loss 1.400369
# iteration 4600 / 5000: loss 1.415731
# iteration 4700 / 5000: loss 1.388336
# iteration 4800 / 5000: loss 1.334582
# iteration 4900 / 5000: loss 1.341295
# Validation accuracy:  0.501

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.26 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplots(nrows=2, ncols=1)

plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from exercise_code.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    fig = plt.figure(figsize=(20,20))
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should aim to achieve a classification accuracy of greater than 50% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).
#
#
# **We highly encourage you to use this opportunity to get a feel for your machine learning system. Consider this kind of tuning as an essential part of getting the most out of your neural network**

# %%
from exercise_code.classifiers.neural_net import TwoLayerNet, neuralnetwork_hyperparameter_tuning

best_net = neuralnetwork_hyperparameter_tuning(X_train, y_train, X_val, y_val)
# Out:
# 0 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0002
# regularization_strength: 0.75
# num_iters: 1000
#
# Train acc: 35.993750000000006 %
# Valid acc: 34.0 %
# ----------
#
# 1 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0002
# regularization_strength: 0.5
# num_iters: 1000
#
# Train acc: 36.59583333333333 %
# Valid acc: 35.8 %
# ----------
#
# 2 / 304 Epoch
# Training
# Predicting
# 3 / 304 Epoch
# Training
# Predicting
# 4 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0004
# regularization_strength: 0.75
# num_iters: 1000
#
# Train acc: 42.981249999999996 %
# Valid acc: 42.8 %
# ----------
#
# 5 / 304 Epoch
# Training
# Predicting
# 6 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0004
# regularization_strength: 0.25
# num_iters: 1000
#
# Train acc: 43.08541666666667 %
# Valid acc: 43.1 %
# ----------
#
# 7 / 304 Epoch
# Training
# Predicting
# 8 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0006000000000000001
# regularization_strength: 0.75
# num_iters: 1000
#
# Train acc: 46.06666666666667 %
# Valid acc: 46.300000000000004 %
# ----------
#
# 9 / 304 Epoch
# Training
# Predicting
# 10 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0006000000000000001
# regularization_strength: 0.25
# num_iters: 1000
#
# Train acc: 46.637499999999996 %
# Valid acc: 46.5 %
# ----------
#
# 11 / 304 Epoch
# Training
# Predicting
# 12 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0008
# regularization_strength: 0.75
# num_iters: 1000
#
# Train acc: 47.56666666666667 %
# Valid acc: 47.5 %
# ----------
#
# 13 / 304 Epoch
# Training
# Predicting
# 14 / 304 Epoch
# Training
# Predicting
# 15 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0008
# regularization_strength: 0.005
# num_iters: 1000
#
# Train acc: 48.53958333333333 %
# Valid acc: 47.9 %
# ----------
#
# 16 / 304 Epoch
# Training
# Predicting
# 17 / 304 Epoch
# Training
# Predicting
# 18 / 304 Epoch
# Training
# Predicting
# 19 / 304 Epoch
# Training
# Predicting
# 20 / 304 Epoch
# Training
# Predicting
# 21 / 304 Epoch
# Training
# Predicting
# 22 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0012000000000000001
# regularization_strength: 0.25
# num_iters: 1000
#
# Train acc: 49.92916666666667 %
# Valid acc: 48.1 %
# ----------
#
# 23 / 304 Epoch
# Training
# Predicting
# 24 / 304 Epoch
# Training
# Predicting
# 25 / 304 Epoch
# Training
# Predicting
# 26 / 304 Epoch
# Training
# Predicting
# 27 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0014000000000000002
# regularization_strength: 0.005
# num_iters: 1000
#
# Train acc: 50.94375 %
# Valid acc: 48.5 %
# ----------
#
# 28 / 304 Epoch
# Training
# Predicting
# 29 / 304 Epoch
# Training
# Predicting
# 30 / 304 Epoch
# Training
# Predicting
# 31 / 304 Epoch
# Training
# Predicting
# 32 / 304 Epoch
# Training
# Predicting
# 33 / 304 Epoch
# Training
# Predicting
# 34 / 304 Epoch
# Training
# Predicting
# 35 / 304 Epoch
# Training
# Predicting
# 36 / 304 Epoch
# Training
# Predicting
# 37 / 304 Epoch
# Training
# Predicting
# 38 / 304 Epoch
# Training
# Predicting
# 39 / 304 Epoch
# Training
# Predicting
# 40 / 304 Epoch
# Training
# Predicting
# 41 / 304 Epoch
# Training
# Predicting
# 42 / 304 Epoch
# Training
# Predicting
# 43 / 304 Epoch
# Training
# Predicting
# 44 / 304 Epoch
# Training
# Predicting
# 45 / 304 Epoch
# Training
# Predicting
# 46 / 304 Epoch
# Training
# Predicting
# 47 / 304 Epoch
# Training
# Predicting
# 48 / 304 Epoch
# Training
# Predicting
# 49 / 304 Epoch
# Training
# Predicting
# 50 / 304 Epoch
# Training
# Predicting
# 51 / 304 Epoch
# Training
# Predicting
# 52 / 304 Epoch
# Training
# Predicting
# 53 / 304 Epoch
# Training
# Predicting
# 54 / 304 Epoch
# Training
# Predicting
# 55 / 304 Epoch
# Training
# Predicting
# 56 / 304 Epoch
# Training
# Predicting
# 57 / 304 Epoch
# Training
# Predicting
# 58 / 304 Epoch
# Training
# Predicting
# 59 / 304 Epoch
# Training
# Predicting
# 60 / 304 Epoch
# Training
# Predicting
# 61 / 304 Epoch
# Training
# Predicting
# 62 / 304 Epoch
# Training
# Predicting
# 63 / 304 Epoch
# Training
# Predicting
# 64 / 304 Epoch
# Training
# Predicting
# 65 / 304 Epoch
# Training
# Predicting
# 66 / 304 Epoch
# Training
# Predicting
# 67 / 304 Epoch
# Training
# Predicting
# 68 / 304 Epoch
# Training
# Predicting
# 69 / 304 Epoch
# Training
# Predicting
# 70 / 304 Epoch
# Training
# Predicting
# 71 / 304 Epoch
# Training
# Predicting
# 72 / 304 Epoch
# Training
# /content/exercise_code/classifiers/neural_net.py:116: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(exps[range(images), y])) / images
# Predicting
# 73 / 304 Epoch
# Training
# Predicting
# 74 / 304 Epoch
# Training
# Predicting
# 75 / 304 Epoch
# Training
# Predicting
# 76 / 304 Epoch
# Training
# Predicting
# 77 / 304 Epoch
# Training
# Predicting
# 78 / 304 Epoch
# Training
# Predicting
# 79 / 304 Epoch
# Training
# Predicting
# 80 / 304 Epoch
# Training
# Predicting
# 81 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0004
# regularization_strength: 0.5
# num_iters: 2500
#
# Train acc: 49.114583333333336 %
# Valid acc: 48.6 %
# ----------
#
# 82 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0004
# regularization_strength: 0.25
# num_iters: 2500
#
# Train acc: 49.485416666666666 %
# Valid acc: 49.6 %
# ----------
#
# 83 / 304 Epoch
# Training
# Predicting
# 84 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0006000000000000001
# regularization_strength: 0.75
# num_iters: 2500
#
# Train acc: 51.19166666666667 %
# Valid acc: 50.1 %
# ----------
#
# 85 / 304 Epoch
# Training
# Predicting
# 86 / 304 Epoch
# Training
# Predicting
# 87 / 304 Epoch
# Training
# Predicting
# 88 / 304 Epoch
# Training
# Predicting
# 89 / 304 Epoch
# Training
# Predicting
# 90 / 304 Epoch
# Training
# Predicting
# 91 / 304 Epoch
# Training
# Predicting
# 92 / 304 Epoch
# Training
# Predicting
# 93 / 304 Epoch
# Training
# Predicting
# 94 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.001
# regularization_strength: 0.25
# num_iters: 2500
#
# Train acc: 54.92083333333333 %
# Valid acc: 50.3 %
# ----------
#
# 95 / 304 Epoch
# Training
# Predicting
# 96 / 304 Epoch
# Training
# Predicting
# 97 / 304 Epoch
# Training
# Predicting
# 98 / 304 Epoch
# Training
# Predicting
# 99 / 304 Epoch
# Training
# Predicting
# 100 / 304 Epoch
# Training
# Predicting
# 101 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0014000000000000002
# regularization_strength: 0.5
# num_iters: 2500
#
# Train acc: 54.0 %
# Valid acc: 51.4 %
# ----------
#
# 102 / 304 Epoch
# Training
# Predicting
# 103 / 304 Epoch
# Training
# Predicting
# 104 / 304 Epoch
# Training
# Predicting
# 105 / 304 Epoch
# Training
# Predicting
# 106 / 304 Epoch
# Training
# Predicting
# 107 / 304 Epoch
# Training
# Predicting
# 108 / 304 Epoch
# Training
# Predicting
# 109 / 304 Epoch
# Training
# Predicting
# 110 / 304 Epoch
# Training
# Predicting
# 111 / 304 Epoch
# Training
# Predicting
# 112 / 304 Epoch
# Training
# Predicting
# 113 / 304 Epoch
# Training
# Predicting
# 114 / 304 Epoch
# Training
# Predicting
# 115 / 304 Epoch
# Training
# Predicting
# 116 / 304 Epoch
# Training
# Predicting
# 117 / 304 Epoch
# Training
# Predicting
# 118 / 304 Epoch
# Training
# Predicting
# 119 / 304 Epoch
# Training
# Predicting
# 120 / 304 Epoch
# Training
# Predicting
# 121 / 304 Epoch
# Training
# Predicting
# 122 / 304 Epoch
# Training
# Predicting
# 123 / 304 Epoch
# Training
# Predicting
# 124 / 304 Epoch
# Training
# Predicting
# 125 / 304 Epoch
# Training
# Predicting
# 126 / 304 Epoch
# Training
# Predicting
# 127 / 304 Epoch
# Training
# Predicting
# 128 / 304 Epoch
# Training
# Predicting
# 129 / 304 Epoch
# Training
# Predicting
# 130 / 304 Epoch
# Training
# Predicting
# 131 / 304 Epoch
# Training
# Predicting
# 132 / 304 Epoch
# Training
# Predicting
# 133 / 304 Epoch
# Training
# Predicting
# 134 / 304 Epoch
# Training
# Predicting
# 135 / 304 Epoch
# Training
# Predicting
# 136 / 304 Epoch
# Training
# Predicting
# 137 / 304 Epoch
# Training
# Predicting
# 138 / 304 Epoch
# Training
# Predicting
# 139 / 304 Epoch
# Training
# Predicting
# 140 / 304 Epoch
# Training
# Predicting
# 141 / 304 Epoch
# Training
# Predicting
# 142 / 304 Epoch
# Training
# Predicting
# 143 / 304 Epoch
# Training
# Predicting
# 144 / 304 Epoch
# Training
# Predicting
# 145 / 304 Epoch
# Training
# Predicting
# 146 / 304 Epoch
# Training
# Predicting
# 147 / 304 Epoch
# Training
# Predicting
# 148 / 304 Epoch
# Training
# Predicting
# 149 / 304 Epoch
# Training
# Predicting
# 150 / 304 Epoch
# Training
# Predicting
# 151 / 304 Epoch
# Training
# Predicting
# 152 / 304 Epoch
# Training
# Predicting
# 153 / 304 Epoch
# Training
# Predicting
# 154 / 304 Epoch
# Training
# Predicting
# 155 / 304 Epoch
# Training
# Predicting
# 156 / 304 Epoch
# Training
# Predicting
# 157 / 304 Epoch
# Training
# Predicting
# 158 / 304 Epoch
# Training
# Predicting
# 159 / 304 Epoch
# Training
# Predicting
# 160 / 304 Epoch
# Training
# Predicting
# 161 / 304 Epoch
# Training
# Predicting
# 162 / 304 Epoch
# Training
# Predicting
# 163 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0006000000000000001
# regularization_strength: 0.005
# num_iters: 5000
#
# Train acc: 57.00208333333333 %
# Valid acc: 52.1 %
# ----------
#
# 164 / 304 Epoch
# Training
# Predicting
# 165 / 304 Epoch
# Training
# Predicting
# ----------
# New best:
# learning_rate: 0.0008
# regularization_strength: 0.5
# num_iters: 5000
#
# Train acc: 56.81666666666667 %
# Valid acc: 53.1 %
# ----------
#
# 166 / 304 Epoch
# Training
# Predicting
# 167 / 304 Epoch
# Training
# Predicting
# 168 / 304 Epoch
# Training
# Predicting
# 169 / 304 Epoch
# Training
# Predicting
# 170 / 304 Epoch
# Training
# Predicting
# 171 / 304 Epoch
# Training
# Predicting
# 172 / 304 Epoch
# Training
# Predicting
# 173 / 304 Epoch
# Training
# Predicting
# 174 / 304 Epoch
# Training
# Predicting
# 175 / 304 Epoch
# Training
# Predicting
# 176 / 304 Epoch
# Training
# Predicting
# 177 / 304 Epoch
# Training
# Predicting
# 178 / 304 Epoch
# Training
# Predicting
# 179 / 304 Epoch
# Training
# Predicting
# 180 / 304 Epoch
# Training
# Predicting
# 181 / 304 Epoch
# Training
# Predicting
# 182 / 304 Epoch
# Training
# Predicting
# 183 / 304 Epoch
# Training
# Predicting
# 184 / 304 Epoch
# Training
# Predicting
# 185 / 304 Epoch
# Training
# Predicting
# 186 / 304 Epoch
# Training
# Predicting
# 187 / 304 Epoch
# Training
# Predicting
# 188 / 304 Epoch
# Training
# Predicting
# 189 / 304 Epoch
# Training
# Predicting
# 190 / 304 Epoch
# Training
# Predicting
# 191 / 304 Epoch
# Training
# Predicting
# 192 / 304 Epoch
# Training
# Predicting
# 193 / 304 Epoch
# Training
# Predicting
# 194 / 304 Epoch
# Training
# Predicting
# 195 / 304 Epoch
# Training
# Predicting
# 196 / 304 Epoch
# Training
# Predicting
# 197 / 304 Epoch
# Training
# Predicting
# 198 / 304 Epoch
# Training
# Predicting
# 199 / 304 Epoch
# Training
# Predicting
# 200 / 304 Epoch
# Training
# Predicting
# 201 / 304 Epoch
# Training
# Predicting
# 202 / 304 Epoch
# Training
# Predicting
# 203 / 304 Epoch
# Training
# Predicting
# 204 / 304 Epoch
# Training
# Predicting
# 205 / 304 Epoch
# Training
# Predicting
# 206 / 304 Epoch
# Training
# Predicting
# 207 / 304 Epoch
# Training
# Predicting
# 208 / 304 Epoch
# Training
# Predicting
# 209 / 304 Epoch
# Training
# Predicting
# 210 / 304 Epoch
# Training
# Predicting
# 211 / 304 Epoch
# Training
# Predicting
# 212 / 304 Epoch
# Training
# Predicting
# 213 / 304 Epoch
# Training
# Predicting
# 214 / 304 Epoch
# Training
# Predicting
# 215 / 304 Epoch
# Training
# Predicting
# 216 / 304 Epoch
# Training
# Predicting
# 217 / 304 Epoch
# Training
# Predicting
# 218 / 304 Epoch
# Training
# Predicting
# 219 / 304 Epoch
# Training
# Predicting
# 220 / 304 Epoch
# Training
# Predicting
# 221 / 304 Epoch
# Training
# Predicting
# 222 / 304 Epoch
# Training
# Predicting
# 223 / 304 Epoch
# Training
# Predicting
# 224 / 304 Epoch
# Training
# Predicting
# 225 / 304 Epoch
# Training
# Predicting
# 226 / 304 Epoch
# Training
# Predicting
# 227 / 304 Epoch
# Training
# Predicting
# 228 / 304 Epoch
# Training
# Predicting
# 229 / 304 Epoch
# Training
# Predicting
# 230 / 304 Epoch
# Training
# Predicting
# 231 / 304 Epoch
# Training
# Predicting
# 232 / 304 Epoch
# Training
# Predicting
# 233 / 304 Epoch
# Training
# Predicting
# 234 / 304 Epoch
# Training
# Predicting
# 235 / 304 Epoch
# Training
# Predicting
# 236 / 304 Epoch
# Training
# Predicting
# 237 / 304 Epoch
# Training
# Predicting
# 238 / 304 Epoch
# Training
# Predicting
# 239 / 304 Epoch
# Training
# Predicting
# 240 / 304 Epoch
# Training
# Predicting
# 241 / 304 Epoch
# Training
# Predicting
# 242 / 304 Epoch
# Training
# Predicting
# 243 / 304 Epoch
# Training
# Predicting
# 244 / 304 Epoch
# Training
# Predicting
# 245 / 304 Epoch
# Training
# Predicting
# 246 / 304 Epoch
# Training
# Predicting
# 247 / 304 Epoch
# Training
# Predicting
# 248 / 304 Epoch
# Training
# Predicting
# 249 / 304 Epoch
# Training
# Predicting
# 250 / 304 Epoch
# Training
# Predicting
# 251 / 304 Epoch
# Training
# Predicting
# 252 / 304 Epoch
# Training
# Predicting
# 253 / 304 Epoch
# Training
# Predicting
# 254 / 304 Epoch
# Training
# Predicting
# 255 / 304 Epoch
# Training
# Predicting
# 256 / 304 Epoch
# Training
# Predicting
# 257 / 304 Epoch
# Training
# Predicting
# 258 / 304 Epoch
# Training
# Predicting
# 259 / 304 Epoch
# Training
# Predicting
# 260 / 304 Epoch
# Training
# Predicting
# 261 / 304 Epoch
# Training
# Predicting
# 262 / 304 Epoch
# Training
# Predicting
# 263 / 304 Epoch
# Training
# Predicting
# 264 / 304 Epoch
# Training
# Predicting
# 265 / 304 Epoch
# Training
# Predicting
# 266 / 304 Epoch
# Training
# Predicting
# 267 / 304 Epoch
# Training
# Predicting
# 268 / 304 Epoch
# Training
# Predicting
# 269 / 304 Epoch
# Training
# Predicting
# 270 / 304 Epoch
# Training
# Predicting
# 271 / 304 Epoch
# Training
# Predicting
# 272 / 304 Epoch
# Training
# Predicting
# 273 / 304 Epoch
# Training
# Predicting
# 274 / 304 Epoch
# Training
# Predicting
# 275 / 304 Epoch
# Training
# Predicting
# 276 / 304 Epoch
# Training
# Predicting
# 277 / 304 Epoch
# Training
# Predicting
# 278 / 304 Epoch
# Training
# Predicting
# 279 / 304 Epoch
# Training
# Predicting
# 280 / 304 Epoch
# Training
# Predicting
# 281 / 304 Epoch
# Training
# Predicting
# 282 / 304 Epoch
# Training
# Predicting
# 283 / 304 Epoch
# Training
# Predicting
# 284 / 304 Epoch
# Training
# Predicting
# 285 / 304 Epoch
# Training
# Predicting
# 286 / 304 Epoch
# Training
# Predicting
# 287 / 304 Epoch
# Training
# Predicting
# 288 / 304 Epoch
# Training
# Predicting
# 289 / 304 Epoch
# Training
# Predicting
# 290 / 304 Epoch
# Training
# Predicting
# 291 / 304 Epoch
# Training
# Predicting
# 292 / 304 Epoch
# Training
# Predicting
# 293 / 304 Epoch
# Training
# Predicting
# 294 / 304 Epoch
# Training
# Predicting
# 295 / 304 Epoch
# Training
# Predicting
# 296 / 304 Epoch
# Training
# Predicting
# 297 / 304 Epoch
# Training
# Predicting
# 298 / 304 Epoch
# Training
# Predicting
# 299 / 304 Epoch
# Training
# Predicting
# 300 / 304 Epoch
# Training
# Predicting
# 301 / 304 Epoch
# Training
# Predicting
# 302 / 304 Epoch
# Training
# Predicting
# 303 / 304 Epoch
# Training
# Predicting
# {(0.0002, 0.75): (0.4947916666666667, 0.48), (0.0002, 0.5): (0.4979166666666667, 0.495), (0.0002, 0.25): (0.49845833333333334, 0.488), (0.0002, 0.005): (0.5051875, 0.494), (0.0004, 0.75): (0.5352916666666667, 0.499), (0.0004, 0.5): (0.5487708333333333, 0.511), (0.0004, 0.25): (0.55525, 0.519), (0.0004, 0.005): (0.56, 0.524), (0.0006000000000000001, 0.75): (0.5649375, 0.509), (0.0006000000000000001, 0.5): (0.5734375, 0.511), (0.0006000000000000001, 0.25): (0.5862083333333333, 0.512), (0.0006000000000000001, 0.005): (0.5887083333333333, 0.5), (0.0008, 0.75): (0.5689166666666666, 0.506), (0.0008, 0.5): (0.5831666666666667, 0.506), (0.0008, 0.25): (0.5985, 0.527), (0.0008, 0.005): (0.6104375, 0.494), (0.001, 0.75): (0.5721875, 0.506), (0.001, 0.5): (0.5912708333333333, 0.508), (0.001, 0.25): (0.6101666666666666, 0.514), (0.001, 0.005): (0.626875, 0.514), (0.0012000000000000001, 0.75): (0.5790625, 0.521), (0.0012000000000000001, 0.5): (0.5949583333333334, 0.524), (0.0012000000000000001, 0.25): (0.6110625, 0.506), (0.0012000000000000001, 0.005): (0.628375, 0.504), (0.0014000000000000002, 0.75): (0.5797291666666666, 0.514), (0.0014000000000000002, 0.5): (0.5979375, 0.522), (0.0014000000000000002, 0.25): (0.6177708333333334, 0.51), (0.0014000000000000002, 0.005): (0.639125, 0.503), (0.0016, 0.75): (0.5758125, 0.511), (0.0016, 0.5): (0.5945416666666666, 0.49), (0.0016, 0.25): (0.6169375, 0.527), (0.0016, 0.005): (0.6404791666666667, 0.495), (0.0018000000000000002, 0.75): (0.5790208333333333, 0.5), (0.0018000000000000002, 0.5): (0.5907708333333334, 0.502), (0.0018000000000000002, 0.25): (0.6137291666666667, 0.499), (0.0018000000000000002, 0.005): (0.6461666666666667, 0.507), (0.002, 0.75): (0.57475, 0.521), (0.002, 0.5): (0.597375, 0.52), (0.002, 0.25): (0.6192916666666667, 0.499), (0.002, 0.005): (0.6484583333333334, 0.504), (0.0022, 0.75): (0.5732916666666666, 0.512), (0.0022, 0.5): (0.5935208333333334, 0.505), (0.0022, 0.25): (0.6135833333333334, 0.521), (0.0022, 0.005): (0.65, 0.504), (0.0024000000000000002, 0.75): (0.5711041666666666, 0.513), (0.0024000000000000002, 0.5): (0.5920625, 0.522), (0.0024000000000000002, 0.25): (0.614125, 0.512), (0.0024000000000000002, 0.005): (0.6482291666666666, 0.497), (0.0026000000000000003, 0.75): (0.573875, 0.518), (0.0026000000000000003, 0.5): (0.5790625, 0.516), (0.0026000000000000003, 0.25): (0.6136875, 0.519), (0.0026000000000000003, 0.005): (0.6533541666666667, 0.52), (0.0028000000000000004, 0.75): (0.5685, 0.502), (0.0028000000000000004, 0.5): (0.584875, 0.506), (0.0028000000000000004, 0.25): (0.6030416666666667, 0.518), (0.0028000000000000004, 0.005): (0.653, 0.512), (0.003, 0.75): (0.5676041666666667, 0.514), (0.003, 0.5): (0.5801875, 0.5), (0.003, 0.25): (0.6173541666666666, 0.507), (0.003, 0.005): (0.6542708333333334, 0.475), (0.0032, 0.75): (0.5604166666666667, 0.492), (0.0032, 0.5): (0.5810416666666667, 0.485), (0.0032, 0.25): (0.5955625, 0.508), (0.0032, 0.005): (0.6493333333333333, 0.513), (0.0034000000000000002, 0.75): (0.5650208333333333, 0.5), (0.0034000000000000002, 0.5): (0.5844166666666667, 0.511), (0.0034000000000000002, 0.25): (0.6135416666666667, 0.504), (0.0034000000000000002, 0.005): (0.65425, 0.487), (0.0036000000000000003, 0.75): (0.5517083333333334, 0.493), (0.0036000000000000003, 0.5): (0.5808541666666667, 0.516), (0.0036000000000000003, 0.25): (0.6019791666666666, 0.503), (0.0036000000000000003, 0.005): (0.6515833333333333, 0.5), (0.0038000000000000004, 0.75): (0.5228958333333333, 0.49), (0.0038000000000000004, 0.5): (0.5648333333333333, 0.496), (0.0038000000000000004, 0.25): (0.593125, 0.506), (0.0038000000000000004, 0.005): (0.6424583333333334, 0.491)}

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Describe what your visualized two-layer-net weights look like, in particular in contrast to the softmax weights of the first exercise of this set.</p>
# </div>

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 50%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.517

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>You might get an error like this:</p>
#     <p>PicklingError: Can't pickle `<class 'exercise_code.classifiers.softmax.SoftmaxClassifier'>`: it's not the same object as exercise_code.classifiers.softmax.SoftmaxClassifier</p>
#     <p>The reason is that we are using autoreload and working on this class during the notebook session. If you get this error simply restart the kernel and rerun the whole script (Kernel -> Restart & Run All) or only the important cells for generating your model.</p>
# </div>

# %%
from exercise_code.model_savers import save_two_layer_net
save_two_layer_net(best_net)

# %% [markdown]
# ## Submission 2
#
# The two layer network is submission 2. To earn the bonus you need to achieve a score higher than __50%__.
