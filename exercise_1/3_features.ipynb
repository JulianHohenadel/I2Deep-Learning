# %% [markdown]
# # Image Features
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir exercise_code
# !mkdir exercise_code/classifiers

# %%
import random
import numpy as np
from exercise_code.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk. However, we don't apply our previous preprocessing steps, as we want to extract custom features later on.

# %%
from exercise_code.data_utils import load_CIFAR10
from exercise_code.vis_utils import visualize_cifar10

def get_CIFAR10_data(num_training=48000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for feature extraction and training.
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = '/content/drive/My Drive/datasets/cifar10'
    X, y = load_CIFAR10(cifar10_dir)
    

    # Our training set will be the first num_train points from the original dataset.
    mask = range(num_training)
    X_train = X[mask]
    y_train = y[mask]
    
    # Our validation set will be num_validation points from the original dataset.
    mask = range(num_training, num_training + num_validation)
    X_val = X[mask]
    y_val = y[mask]
    
    # Our test set will be num_test points from the original dataset.
    mask = range(num_training + num_validation, num_training + num_validation + num_test)
    X_test = X[mask]
    y_test = y[mask]

    return X, y, X_train, y_train, X_val, y_val, X_test, y_test

# Invoke the above function to get our data.
X_raw, y_raw, X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)

# visualize raw data
visualize_cifar10(X_raw, y_raw)
# Out:
# Train data shape:  (48000, 32, 32, 3)
# Train labels shape:  (48000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from exercise_code.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000/48000 images
# Done extracting features for 2000/48000 images
# Done extracting features for 3000/48000 images
# Done extracting features for 4000/48000 images
# Done extracting features for 5000/48000 images
# Done extracting features for 6000/48000 images
# Done extracting features for 7000/48000 images
# Done extracting features for 8000/48000 images
# Done extracting features for 9000/48000 images
# Done extracting features for 10000/48000 images
# Done extracting features for 11000/48000 images
# Done extracting features for 12000/48000 images
# Done extracting features for 13000/48000 images
# Done extracting features for 14000/48000 images
# Done extracting features for 15000/48000 images
# Done extracting features for 16000/48000 images
# Done extracting features for 17000/48000 images
# Done extracting features for 18000/48000 images
# Done extracting features for 19000/48000 images
# Done extracting features for 20000/48000 images
# Done extracting features for 21000/48000 images
# Done extracting features for 22000/48000 images
# Done extracting features for 23000/48000 images
# Done extracting features for 24000/48000 images
# Done extracting features for 25000/48000 images
# Done extracting features for 26000/48000 images
# Done extracting features for 27000/48000 images
# Done extracting features for 28000/48000 images
# Done extracting features for 29000/48000 images
# Done extracting features for 30000/48000 images
# Done extracting features for 31000/48000 images
# Done extracting features for 32000/48000 images
# Done extracting features for 33000/48000 images
# Done extracting features for 34000/48000 images
# Done extracting features for 35000/48000 images
# Done extracting features for 36000/48000 images
# Done extracting features for 37000/48000 images
# Done extracting features for 38000/48000 images
# Done extracting features for 39000/48000 images
# Done extracting features for 40000/48000 images
# Done extracting features for 41000/48000 images
# Done extracting features for 42000/48000 images
# Done extracting features for 43000/48000 images
# Done extracting features for 44000/48000 images
# Done extracting features for 45000/48000 images
# Done extracting features for 46000/48000 images
# Done extracting features for 47000/48000 images

# %% [markdown]
# ## Train a Softmax classifier on features
# Using the multiclass Softmax code developed earlier in the assignment, train a Softmax classifier on top of the features extracted above; this should achieve better results than training the classifier directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength. You can 
# reuse the softmax_hyperparameter_tuning that you implemented in
# exercise_code.classifiers.softmax

from exercise_code.classifiers.softmax import SoftmaxClassifier, softmax_hyperparameter_tuning

best_softmax = None

################################################################################
# TODO: Train a softmax classifier on the features and tune hyperparameters to #
# obtain a strong model. You can alter and reuse the                           #
# softmax_hyperparameter_tuning function. Store your best network in the       #
# best_softmax variable.                                                       #
################################################################################

# best_softmax, results, all_classifiers = softmax_hyperparameter_tuning(X_train_feats, y_train, X_val_feats, y_val)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# %%
# Evaluate your trained classifier on the test set
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    if len(idxs) > 0:
        idxs = np.random.choice(idxs, min(examples_per_class, len(idxs)), replace=False)
    else:
        idxs = []
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Describe the misclassification results that you see. Do they make sense?</p>
# </div>

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set.
#
# Note that in the neural net class we have used explicit biases. In the preprocessing of this exercise we have also added a bias dimension to the input, such that we don't have to consider an explicit bias in the linear classifier above. The neural net therefore has an additional parameter in the first layer (the additional bias term), which after all does not matter, as both bias terms can be learned and behave almost the same as having a single bias term.

# %%
from exercise_code.classifiers.neural_net import TwoLayerNet, neuralnetwork_hyperparameter_tuning

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# validate various parameters as in previous sections. Store your best         #
# model in the best_net variable.                                              #
################################################################################

best_net = neuralnetwork_hyperparameter_tuning(X_train_feats, y_train, X_val_feats, y_val)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# 0 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 64
# learning_rate: 0.1
# regularization_strength: 5e-08
# num_iters: 7500
#
# Train acc: 61.022916666666674 %
# Valid acc: 57.199999999999996 %
# ---------------
#
# 1 / 351 Epoch
# Training
# Predicting
# 2 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 64
# learning_rate: 0.1
# regularization_strength: 5e-10
# num_iters: 7500
#
# Train acc: 61.199999999999996 %
# Valid acc: 57.99999999999999 %
# ---------------
#
# 3 / 351 Epoch
# Training
# Predicting
# 4 / 351 Epoch
# Training
# Predicting
# 5 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 64
# learning_rate: 0.1
# regularization_strength: 5e-10
# num_iters: 10000
#
# Train acc: 61.550000000000004 %
# Valid acc: 59.5 %
# ---------------
#
# 6 / 351 Epoch
# Training
# Predicting
# 7 / 351 Epoch
# Training
# Predicting
# 8 / 351 Epoch
# Training
# Predicting
# 9 / 351 Epoch
# Training
# Predicting
# 10 / 351 Epoch
# Training
# Predicting
# 11 / 351 Epoch
# Training
# Predicting
# 12 / 351 Epoch
# Training
# Predicting
# 13 / 351 Epoch
# Training
# Predicting
# 14 / 351 Epoch
# Training
# Predicting
# 15 / 351 Epoch
# Training
# Predicting
# 16 / 351 Epoch
# Training
# Predicting
# 17 / 351 Epoch
# Training
# Predicting
# 18 / 351 Epoch
# Training
# Predicting
# 19 / 351 Epoch
# Training
# Predicting
# 20 / 351 Epoch
# Training
# Predicting
# 21 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 64
# learning_rate: 0.15
# regularization_strength: 5e-08
# num_iters: 10000
#
# Train acc: 64.43333333333334 %
# Valid acc: 60.199999999999996 %
# ---------------
#
# 22 / 351 Epoch
# Training
# Predicting
# 23 / 351 Epoch
# Training
# Predicting
# 24 / 351 Epoch
# Training
# Predicting
# 25 / 351 Epoch
# Training
# Predicting
# 26 / 351 Epoch
# Training
# Predicting
# 27 / 351 Epoch
# Training
# Predicting
# 28 / 351 Epoch
# Training
# Predicting
# 29 / 351 Epoch
# Training
# Predicting
# 30 / 351 Epoch
# Training
# Predicting
# 31 / 351 Epoch
# Training
# Predicting
# 32 / 351 Epoch
# Training
# Predicting
# 33 / 351 Epoch
# Training
# Predicting
# 34 / 351 Epoch
# Training
# Predicting
# 35 / 351 Epoch
# Training
# Predicting
# 36 / 351 Epoch
# Training
# Predicting
# 37 / 351 Epoch
# Training
# Predicting
# 38 / 351 Epoch
# Training
# Predicting
# 39 / 351 Epoch
# Training
# Predicting
# 40 / 351 Epoch
# Training
# Predicting
# 41 / 351 Epoch
# Training
# Predicting
# 42 / 351 Epoch
# Training
# Predicting
# 43 / 351 Epoch
# Training
# Predicting
# 44 / 351 Epoch
# Training
# Predicting
# 45 / 351 Epoch
# Training
# Predicting
# 46 / 351 Epoch
# Training
# Predicting
# 47 / 351 Epoch
# Training
# Predicting
# 48 / 351 Epoch
# Training
# Predicting
# 49 / 351 Epoch
# Training
# Predicting
# 50 / 351 Epoch
# Training
# Predicting
# 51 / 351 Epoch
# Training
# Predicting
# 52 / 351 Epoch
# Training
# Predicting
# 53 / 351 Epoch
# Training
# Predicting
# 54 / 351 Epoch
# Training
# Predicting
# 55 / 351 Epoch
# Training
# Predicting
# 56 / 351 Epoch
# Training
# Predicting
# 57 / 351 Epoch
# Training
# Predicting
# 58 / 351 Epoch
# Training
# Predicting
# 59 / 351 Epoch
# Training
# Predicting
# 60 / 351 Epoch
# Training
# Predicting
# 61 / 351 Epoch
# Training
# Predicting
# 62 / 351 Epoch
# Training
# Predicting
# 63 / 351 Epoch
# Training
# Predicting
# 64 / 351 Epoch
# Training
# Predicting
# 65 / 351 Epoch
# Training
# Predicting
# 66 / 351 Epoch
# Training
# Predicting
# 67 / 351 Epoch
# Training
# Predicting
# 68 / 351 Epoch
# Training
# Predicting
# 69 / 351 Epoch
# Training
# Predicting
# 70 / 351 Epoch
# Training
# Predicting
# 71 / 351 Epoch
# Training
# Predicting
# 72 / 351 Epoch
# Training
# Predicting
# 73 / 351 Epoch
# Training
# Predicting
# 74 / 351 Epoch
# Training
# Predicting
# 75 / 351 Epoch
# Training
# Predicting
# 76 / 351 Epoch
# Training
# Predicting
# 77 / 351 Epoch
# Training
# Predicting
# 78 / 351 Epoch
# Training
# Predicting
# 79 / 351 Epoch
# Training
# Predicting
# 80 / 351 Epoch
# Training
# Predicting
# 81 / 351 Epoch
# Training
# Predicting
# 82 / 351 Epoch
# Training
# Predicting
# 83 / 351 Epoch
# Training
# Predicting
# 84 / 351 Epoch
# Training
# Predicting
# 85 / 351 Epoch
# Training
# Predicting
# 86 / 351 Epoch
# Training
# Predicting
# 87 / 351 Epoch
# Training
# Predicting
# 88 / 351 Epoch
# Training
# Predicting
# 89 / 351 Epoch
# Training
# Predicting
# 90 / 351 Epoch
# Training
# Predicting
# 91 / 351 Epoch
# Training
# Predicting
# 92 / 351 Epoch
# Training
# Predicting
# 93 / 351 Epoch
# Training
# Predicting
# 94 / 351 Epoch
# Training
# Predicting
# 95 / 351 Epoch
# Training
# Predicting
# 96 / 351 Epoch
# Training
# Predicting
# 97 / 351 Epoch
# Training
# Predicting
# 98 / 351 Epoch
# Training
# Predicting
# 99 / 351 Epoch
# Training
# Predicting
# 100 / 351 Epoch
# Training
# Predicting
# 101 / 351 Epoch
# Training
# Predicting
# 102 / 351 Epoch
# Training
# Predicting
# 103 / 351 Epoch
# Training
# Predicting
# 104 / 351 Epoch
# Training
# Predicting
# 105 / 351 Epoch
# Training
# Predicting
# 106 / 351 Epoch
# Training
# Predicting
# 107 / 351 Epoch
# Training
# Predicting
# 108 / 351 Epoch
# Training
# Predicting
# 109 / 351 Epoch
# Training
# Predicting
# 110 / 351 Epoch
# Training
# Predicting
# 111 / 351 Epoch
# Training
# Predicting
# 112 / 351 Epoch
# Training
# Predicting
# 113 / 351 Epoch
# Training
# Predicting
# 114 / 351 Epoch
# Training
# Predicting
# 115 / 351 Epoch
# Training
# Predicting
# 116 / 351 Epoch
# Training
# Predicting
# 117 / 351 Epoch
# Training
# Predicting
# 118 / 351 Epoch
# Training
# Predicting
# 119 / 351 Epoch
# Training
# Predicting
# 120 / 351 Epoch
# Training
# Predicting
# 121 / 351 Epoch
# Training
# Predicting
# 122 / 351 Epoch
# Training
# Predicting
# 123 / 351 Epoch
# Training
# Predicting
# 124 / 351 Epoch
# Training
# Predicting
# 125 / 351 Epoch
# Training
# Predicting
# 126 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.125
# regularization_strength: 5e-08
# num_iters: 7500
#
# Train acc: 65.60833333333333 %
# Valid acc: 60.4 %
# ---------------
#
# 127 / 351 Epoch
# Training
# Predicting
# 128 / 351 Epoch
# Training
# Predicting
# 129 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.125
# regularization_strength: 5e-08
# num_iters: 10000
#
# Train acc: 67.09583333333333 %
# Valid acc: 60.5 %
# ---------------
#
# 130 / 351 Epoch
# Training
# Predicting
# 131 / 351 Epoch
# Training
# Predicting
# 132 / 351 Epoch
# Training
# Predicting
# 133 / 351 Epoch
# Training
# Predicting
# 134 / 351 Epoch
# Training
# Predicting
# 135 / 351 Epoch
# Training
# Predicting
# 136 / 351 Epoch
# Training
# Predicting
# 137 / 351 Epoch
# Training
# Predicting
# 138 / 351 Epoch
# Training
# Predicting
# 139 / 351 Epoch
# Training
# Predicting
# 140 / 351 Epoch
# Training
# Predicting
# 141 / 351 Epoch
# Training
# Predicting
# 142 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.15
# regularization_strength: 5e-09
# num_iters: 12500
#
# Train acc: 69.52916666666667 %
# Valid acc: 60.6 %
# ---------------
#
# 143 / 351 Epoch
# Training
# Predicting
# 144 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.175
# regularization_strength: 5e-08
# num_iters: 7500
#
# Train acc: 68.81458333333333 %
# Valid acc: 60.9 %
# ---------------
#
# 145 / 351 Epoch
# Training
# Predicting
# 146 / 351 Epoch
# Training
# Predicting
# 147 / 351 Epoch
# Training
# Predicting
# 148 / 351 Epoch
# Training
# Predicting
# 149 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.175
# regularization_strength: 5e-10
# num_iters: 10000
#
# Train acc: 70.36666666666666 %
# Valid acc: 61.0 %
# ---------------
#
# 150 / 351 Epoch
# Training
# Predicting
# 151 / 351 Epoch
# Training
# Predicting
# 152 / 351 Epoch
# Training
# Predicting
# 153 / 351 Epoch
# Training
# Predicting
# 154 / 351 Epoch
# Training
# Predicting
# 155 / 351 Epoch
# Training
# Predicting
# 156 / 351 Epoch
# Training
# Predicting
# 157 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 128
# learning_rate: 0.19999999999999998
# regularization_strength: 5e-09
# num_iters: 10000
#
# Train acc: 71.26458333333333 %
# Valid acc: 61.3 %
# ---------------
#
# 158 / 351 Epoch
# Training
# Predicting
# 159 / 351 Epoch
# Training
# Predicting
# 160 / 351 Epoch
# Training
# Predicting
# 161 / 351 Epoch
# Training
# Predicting
# 162 / 351 Epoch
# Training
# Predicting
# 163 / 351 Epoch
# Training
# Predicting
# 164 / 351 Epoch
# Training
# Predicting
# 165 / 351 Epoch
# Training
# Predicting
# 166 / 351 Epoch
# Training
# Predicting
# 167 / 351 Epoch
# Training
# Predicting
# 168 / 351 Epoch
# Training
# Predicting
# 169 / 351 Epoch
# Training
# Predicting
# 170 / 351 Epoch
# Training
# Predicting
# 171 / 351 Epoch
# Training
# Predicting
# 172 / 351 Epoch
# Training
# Predicting
# 173 / 351 Epoch
# Training
# Predicting
# 174 / 351 Epoch
# Training
# Predicting
# 175 / 351 Epoch
# Training
# Predicting
# 176 / 351 Epoch
# Training
# Predicting
# 177 / 351 Epoch
# Training
# Predicting
# 178 / 351 Epoch
# Training
# Predicting
# 179 / 351 Epoch
# Training
# Predicting
# 180 / 351 Epoch
# Training
# Predicting
# 181 / 351 Epoch
# Training
# Predicting
# 182 / 351 Epoch
# Training
# Predicting
# 183 / 351 Epoch
# Training
# Predicting
# 184 / 351 Epoch
# Training
# Predicting
# 185 / 351 Epoch
# Training
# Predicting
# 186 / 351 Epoch
# Training
# Predicting
# 187 / 351 Epoch
# Training
# Predicting
# 188 / 351 Epoch
# Training
# Predicting
# 189 / 351 Epoch
# Training
# Predicting
# 190 / 351 Epoch
# Training
# Predicting
# 191 / 351 Epoch
# Training
# Predicting
# 192 / 351 Epoch
# Training
# Predicting
# 193 / 351 Epoch
# Training
# Predicting
# 194 / 351 Epoch
# Training
# Predicting
# 195 / 351 Epoch
# Training
# Predicting
# 196 / 351 Epoch
# Training
# Predicting
# 197 / 351 Epoch
# Training
# Predicting
# 198 / 351 Epoch
# Training
# Predicting
# 199 / 351 Epoch
# Training
# Predicting
# 200 / 351 Epoch
# Training
# Predicting
# 201 / 351 Epoch
# Training
# Predicting
# 202 / 351 Epoch
# Training
# Predicting
# 203 / 351 Epoch
# Training
# Predicting
# 204 / 351 Epoch
# Training
# Predicting
# 205 / 351 Epoch
# Training
# Predicting
# 206 / 351 Epoch
# Training
# Predicting
# 207 / 351 Epoch
# Training
# Predicting
# 208 / 351 Epoch
# Training
# Predicting
# 209 / 351 Epoch
# Training
# Predicting
# 210 / 351 Epoch
# Training
# Predicting
# 211 / 351 Epoch
# Training
# Predicting
# 212 / 351 Epoch
# Training
# Predicting
# 213 / 351 Epoch
# Training
# Predicting
# 214 / 351 Epoch
# Training
# Predicting
# 215 / 351 Epoch
# Training
# Predicting
# 216 / 351 Epoch
# Training
# Predicting
# 217 / 351 Epoch
# Training
# Predicting
# 218 / 351 Epoch
# Training
# Predicting
# 219 / 351 Epoch
# Training
# Predicting
# 220 / 351 Epoch
# Training
# Predicting
# 221 / 351 Epoch
# Training
# Predicting
# 222 / 351 Epoch
# Training
# Predicting
# 223 / 351 Epoch
# Training
# Predicting
# 224 / 351 Epoch
# Training
# Predicting
# 225 / 351 Epoch
# Training
# Predicting
# 226 / 351 Epoch
# Training
# Predicting
# 227 / 351 Epoch
# Training
# Predicting
# 228 / 351 Epoch
# Training
# Predicting
# 229 / 351 Epoch
# Training
# Predicting
# 230 / 351 Epoch
# Training
# Predicting
# 231 / 351 Epoch
# Training
# Predicting
# 232 / 351 Epoch
# Training
# Predicting
# 233 / 351 Epoch
# Training
# Predicting
# 234 / 351 Epoch
# Training
# Predicting
# 235 / 351 Epoch
# Training
# Predicting
# 236 / 351 Epoch
# Training
# Predicting
# 237 / 351 Epoch
# Training
# Predicting
# 238 / 351 Epoch
# Training
# Predicting
# 239 / 351 Epoch
# Training
# Predicting
# 240 / 351 Epoch
# Training
# Predicting
# 241 / 351 Epoch
# Training
# Predicting
# 242 / 351 Epoch
# Training
# Predicting
# 243 / 351 Epoch
# Training
# Predicting
# 244 / 351 Epoch
# Training
# Predicting
# 245 / 351 Epoch
# Training
# Predicting
# 246 / 351 Epoch
# Training
# Predicting
# 247 / 351 Epoch
# Training
# Predicting
# 248 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.125
# regularization_strength: 5e-10
# num_iters: 10000
#
# Train acc: 69.96041666666667 %
# Valid acc: 61.4 %
# ---------------
#
# 249 / 351 Epoch
# Training
# Predicting
# 250 / 351 Epoch
# Training
# Predicting
# 251 / 351 Epoch
# Training
# Predicting
# 252 / 351 Epoch
# Training
# Predicting
# 253 / 351 Epoch
# Training
# Predicting
# 254 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.15
# regularization_strength: 5e-10
# num_iters: 7500
#
# Train acc: 70.8875 %
# Valid acc: 61.7 %
# ---------------
#
# 255 / 351 Epoch
# Training
# Predicting
# 256 / 351 Epoch
# Training
# Predicting
# 257 / 351 Epoch
# Training
# Predicting
# 258 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.15
# regularization_strength: 5e-08
# num_iters: 12500
#
# Train acc: 73.52291666666667 %
# Valid acc: 61.8 %
# ---------------
#
# 259 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.15
# regularization_strength: 5e-09
# num_iters: 12500
#
# Train acc: 73.79166666666667 %
# Valid acc: 62.2 %
# ---------------
#
# 260 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.15
# regularization_strength: 5e-10
# num_iters: 12500
#
# Train acc: 74.00208333333333 %
# Valid acc: 62.6 %
# ---------------
#
# 261 / 351 Epoch
# Training
# Predicting
# 262 / 351 Epoch
# Training
# Predicting
# 263 / 351 Epoch
# Training
# Predicting
# 264 / 351 Epoch
# Training
# Predicting
# 265 / 351 Epoch
# Training
# Predicting
# 266 / 351 Epoch
# Training
# Predicting
# 267 / 351 Epoch
# Training
# Predicting
# 268 / 351 Epoch
# Training
# Predicting
# 269 / 351 Epoch
# Training
# Predicting
# 270 / 351 Epoch
# Training
# Predicting
# 271 / 351 Epoch
# Training
# Predicting
# 272 / 351 Epoch
# Training
# Predicting
# 273 / 351 Epoch
# Training
# Predicting
# 274 / 351 Epoch
# Training
# Predicting
# 275 / 351 Epoch
# Training
# Predicting
# 276 / 351 Epoch
# Training
# Predicting
# 277 / 351 Epoch
# Training
# Predicting
# 278 / 351 Epoch
# Training
# Predicting
# 279 / 351 Epoch
# Training
# Predicting
# 280 / 351 Epoch
# Training
# Predicting
# 281 / 351 Epoch
# Training
# Predicting
# 282 / 351 Epoch
# Training
# Predicting
# 283 / 351 Epoch
# Training
# Predicting
# 284 / 351 Epoch
# Training
# Predicting
# 285 / 351 Epoch
# Training
# Predicting
# 286 / 351 Epoch
# Training
# Predicting
# 287 / 351 Epoch
# Training
# Predicting
# 288 / 351 Epoch
# Training
# Predicting
# 289 / 351 Epoch
# Training
# Predicting
# 290 / 351 Epoch
# Training
# Predicting
# ---------------
# New best:
# hidden_size: 256
# learning_rate: 0.24999999999999997
# regularization_strength: 5e-10
# num_iters: 7500
#
# Train acc: 77.94583333333334 %
# Valid acc: 62.7 %
# ---------------
#
# 291 / 351 Epoch
# Training
# Predicting
# 292 / 351 Epoch
# Training
# Predicting
# 293 / 351 Epoch
# Training
# Predicting
# 294 / 351 Epoch
# Training
# Predicting
# 295 / 351 Epoch
# Training
# Predicting
# 296 / 351 Epoch
# Training
# Predicting
# 297 / 351 Epoch
# Training
# Predicting
# 298 / 351 Epoch
# Training
# Predicting
# 299 / 351 Epoch
# Training
# Predicting
# 300 / 351 Epoch
# Training
# Predicting
# 301 / 351 Epoch
# Training
# Predicting
# 302 / 351 Epoch
# Training
# Predicting
# 303 / 351 Epoch
# Training
# Predicting
# 304 / 351 Epoch
# Training
# Predicting
# 305 / 351 Epoch
# Training
# Predicting
# 306 / 351 Epoch
# Training
# Predicting
# 307 / 351 Epoch
# Training
# Predicting
# 308 / 351 Epoch
# Training
# Predicting
# 309 / 351 Epoch
# Training
# Predicting
# 310 / 351 Epoch
# Training
# Predicting
# 311 / 351 Epoch
# Training
# Predicting
# 312 / 351 Epoch
# Training
# Predicting
# 313 / 351 Epoch
# Training
# Predicting
# 314 / 351 Epoch
# Training
# Predicting
# 315 / 351 Epoch
# Training
# Predicting
# 316 / 351 Epoch
# Training
# Predicting
# 317 / 351 Epoch
# Training
# Predicting
# 318 / 351 Epoch
# Training
# Predicting
# 319 / 351 Epoch
# Training
# Predicting
# 320 / 351 Epoch
# Training
# Predicting
# 321 / 351 Epoch
# Training
# Predicting
# 322 / 351 Epoch
# Training
# Predicting
# 323 / 351 Epoch
# Training
# Predicting
# 324 / 351 Epoch
# Training
# Predicting
# 325 / 351 Epoch
# Training
# Predicting
# 326 / 351 Epoch
# Training
# Predicting
# 327 / 351 Epoch
# Training
# Predicting
# 328 / 351 Epoch
# Training
# Predicting
# 329 / 351 Epoch
# Training
# Predicting
# 330 / 351 Epoch
# Training
# Predicting
# 331 / 351 Epoch
# Training
# Predicting
# 332 / 351 Epoch
# Training
# Predicting
# 333 / 351 Epoch
# Training
# Predicting
# 334 / 351 Epoch
# Training
# Predicting
# 335 / 351 Epoch
# Training
# Predicting
# 336 / 351 Epoch
# Training
# Predicting
# 337 / 351 Epoch
# Training
# Predicting
# 338 / 351 Epoch
# Training
# Predicting
# 339 / 351 Epoch
# Training
# Predicting
# 340 / 351 Epoch
# Training
# Predicting
# 341 / 351 Epoch
# Training
# Predicting
# 342 / 351 Epoch
# Training
# Predicting
# 343 / 351 Epoch
# Training
# Predicting
# 344 / 351 Epoch
# Training
# Predicting
# 345 / 351 Epoch
# Training
# Predicting
# 346 / 351 Epoch
# Training
# Predicting
# 347 / 351 Epoch
# Training
# Predicting
# 348 / 351 Epoch
# Training
# Predicting
# 349 / 351 Epoch
# Training
# Predicting
# 350 / 351 Epoch
# Training
# Predicting
# {(0.1, 5e-10): (0.6761875, 0.608),
#  (0.1, 5e-09): (0.6717083333333334, 0.601),
#  (0.1, 5e-08): (0.6766666666666666, 0.608),
#  (0.125, 5e-10): (0.7059791666666667, 0.61),
#  (0.125, 5e-09): (0.711125, 0.605),
#  (0.125, 5e-08): (0.7086666666666667, 0.607),
#  (0.15, 5e-10): (0.7400208333333333, 0.626),
#  (0.15, 5e-09): (0.7379166666666667, 0.622),
#  (0.15, 5e-08): (0.7352291666666667, 0.618),
#  (0.175, 5e-10): (0.7629375, 0.62),
#  (0.175, 5e-09): (0.763125, 0.61),
#  (0.175, 5e-08): (0.7656458333333334, 0.611),
#  (0.19999999999999998, 5e-10): (0.7842916666666667, 0.602),
#  (0.19999999999999998, 5e-09): (0.7856458333333334, 0.608),
#  (0.19999999999999998, 5e-08): (0.786375, 0.607),
#  (0.22499999999999998, 5e-10): (0.8022916666666666, 0.592),
#  (0.22499999999999998, 5e-09): (0.8044583333333334, 0.593),
#  (0.22499999999999998, 5e-08): (0.7991875, 0.587),
#  (0.24999999999999997, 5e-10): (0.8204375, 0.588),
#  (0.24999999999999997, 5e-09): (0.820875, 0.623),
#  (0.24999999999999997, 5e-08): (0.8204166666666667, 0.596),
#  (0.27499999999999997, 5e-10): (0.8331875, 0.578),
#  (0.27499999999999997, 5e-09): (0.8286458333333333, 0.597),
#  (0.27499999999999997, 5e-08): (0.8318958333333333, 0.592),
#  (0.29999999999999993, 5e-10): (0.8457708333333334, 0.591),
#  (0.29999999999999993, 5e-09): (0.8435416666666666, 0.574),
#  (0.29999999999999993, 5e-08): (0.84475, 0.581),
#  (0.32499999999999996, 5e-10): (0.858375, 0.568),
#  (0.32499999999999996, 5e-09): (0.8585625, 0.583),
#  (0.32499999999999996, 5e-08): (0.8545625, 0.581),
#  (0.35, 5e-10): (0.8664375, 0.566),
#  (0.35, 5e-09): (0.8670833333333333, 0.558),
#  (0.35, 5e-08): (0.8657916666666666, 0.592),
#  (0.3749999999999999, 5e-10): (0.8745208333333333, 0.555),
#  (0.3749999999999999, 5e-09): (0.8749583333333333, 0.582),
#  (0.3749999999999999, 5e-08): (0.8783333333333333, 0.569),
#  (0.3999999999999999, 5e-10): (0.8849166666666667, 0.584),
#  (0.3999999999999999, 5e-09): (0.8843125, 0.58),
#  (0.3999999999999999, 5e-08): (0.8794166666666666, 0.583)}

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.
test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print("Test accuracy: ", test_acc)
# Out:
# Test accuracy:  0.607

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training you can save your model.
# You need to get a score of at least **55%** to pass this submission.
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>You might get an error like this:</p>
#     <p>PicklingError: Can't pickle ...</p>
#     <p>The reason is that we are using autoreload and working on this class during the notebook session. If you get this error simply restart the kernel and rerun the whole script (Kernel -> Restart & Run All) or only the important cells for generating your model.</p>
# </div>

# %%
from exercise_code.model_savers import save_feature_neural_net
save_feature_neural_net(best_net)

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 18:46:01 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
